# %%
import os
project_path=os.getcwd()

# %%
project_path=join(project_path,"google trends\\google trends")
os.path.join(project_path)
# Out:
# 'E:\\minor\\proj\\google trends\\google trends'

# %%
df = pd.read_csv(os.path.join(project_path,"AL_mosquito.csv"))

# %%
df.head()
# Out:
#         Category: All categories
# Month       mosquito: (Maranhão)
# 2004-01                        0
# 2004-02                        0
# 2004-03                        0
# 2004-04                        0

# %%
import pandas as pd
import os
# import pycountry

# Define a mapping for ISO 3166-2:BR state codes to state names
state_code_to_name = {
    "AC": "State of Acre", "AL": "State of Alagoas", "AP": "State of Amapá",
    "AM": "State of Amazonas", "BA": "State of Bahia", "CE": "State of Ceará",
    "DF": "Federal District", "ES": "State of Espírito Santo", "GO": "State of Goiás",
    "MA": "State of Maranhão", "MT": "State of Mato Grosso", "MS": "State of Mato Grosso do Sul",
    "MG": "State of Minas Gerais", "PA": "State of Pará", "PB": "State of Paraíba",
    "PR": "State of Paraná", "PE": "State of Pernambuco", "PI": "State of Piauí",
    "RJ": "State of Rio de Janeiro", "RN": "State of Rio Grande do Norte",
    "RS": "State of Rio Grande do Sul", "RO": "State of Rondônia", "RR": "State of Roraima",
    "SC": "State of Santa Catarina", "SP": "State of São Paulo", "SE": "State of Sergipe",
    "TO": "State of Tocantins"
}
state_code_to_name2 = {
    "AC": "Acre", "AL": "Alagoas", "AP": "Amapá",
    "AM": "Amazonas", "BA": "Bahia", "CE": "Ceará",
    "DF": "Federal District", "ES": "Espírito Santo", "GO": "Goiás",
    "MA": "Maranhão", "MT": "Mato Grosso", "MS": "Mato Grosso do Sul",
    "MG": "Minas Gerais", "PA": "Pará", "PB": "Paraíba",
    "PR": "Paraná", "PE": "Pernambuco", "PI": "Piauí",
    "RJ": "Rio de Janeiro", "RN": "Rio Grande do Norte",
    "RS": "Rio Grande do Sul", "RO": "Rondônia", "RR": "Roraima",
    "SC": "Santa Catarina", "SP": "São Paulo", "SE": "Sergipe",
    "TO": "Tocantins"
}
# # Define the project path
# project_path = os.getcwd()
# project_path = os.path.join(project_path, "google trends", "google trends")

# # Load the CSV file
# # file_name = "AL_sintomas_dengue.csv"
# file_name = "AL_mosquito.csv"
# df = pd.read_csv(os.path.join(project_path, file_name), index_col=0)

# # Convert the index to a column
# df.reset_index(inplace=True)

# # Extract the state code and category from the file name
# file_state_code, *file_category = file_name.split('.')[0].split('_')
# file_category = ' '.join(file_category)

# # Extract the corresponding state name and category from the first entry
# first_entry = df.iloc[0, 1]  # Get the first value in the "Category: All categories" column
# entry_category, entry_state = first_entry.split(':', 1)
# entry_state = entry_state.strip(" ()")  # Remove parentheses and whitespace

# # Verify the match
# is_state_match = state_code_to_name[file_state_code] == entry_state or state_code_to_name2[file_state_code] == entry_state
# is_category_match = file_category.lower() == entry_category.strip().lower()

# # Output results
# print("File Name:", file_name)
# print("First Entry in 'Category: All categories':", first_entry)
# print("State Match:", is_state_match)
# print("Category Match:", is_category_match)
# print("Overall Match:", is_state_match and is_category_match)

# # Convert the first row to column names
# df.columns = df.iloc[0]
# df = df[1:]  # Drop the first row as it's now used as the header

# entry_category=entry_category.split(' ')
# entry_category='_'.join(entry_category)
# entry_state=entry_state.split(' ')
# entry_state='_'.join(entry_state)


# # Rename the second column by appending "score"
# df.columns = [df.columns[0]] + [f"{entry_category} {entry_state} score"]

# column_name = df.columns[1]  # Get the name of the second column
# df[column_name] = pd.to_numeric(df[column_name], errors='coerce').astype('Int64')

# # # Display the updated DataFrame
# df.head()


print(len(state_code_to_name))
# Out:
# 27

# %%
import os
import pandas as pd

# Define mappings for state codes to state names
state_code_to_name = {
    "AC": "State of Acre", "AL": "State of Alagoas", "AP": "State of Amapá",
    "AM": "State of Amazonas", "BA": "State of Bahia", "CE": "State of Ceará",
    "DF": "Federal District", "ES": "State of Espírito Santo", "GO": "State of Goiás",
    "MA": "State of Maranhão", "MT": "State of Mato Grosso", "MS": "State of Mato Grosso do Sul",
    "MG": "State of Minas Gerais", "PA": "State of Pará", "PB": "State of Paraíba",
    "PR": "State of Paraná", "PE": "State of Pernambuco", "PI": "State of Piauí",
    "RJ": "State of Rio de Janeiro", "RN": "State of Rio Grande do Norte",
    "RS": "State of Rio Grande do Sul", "RO": "State of Rondônia", "RR": "State of Roraima",
    "SC": "State of Santa Catarina", "SP": "State of São Paulo", "SE": "State of Sergipe",
    "TO": "State of Tocantins"
}
state_code_to_name2 = {
    "AC": "Acre", "AL": "Alagoas", "AP": "Amapá",
    "AM": "Amazonas", "BA": "Bahia", "CE": "Ceará",
    "DF": "Federal District", "ES": "Espírito Santo", "GO": "Goiás",
    "MA": "Maranhão", "MT": "Mato Grosso", "MS": "Mato Grosso do Sul",
    "MG": "Minas Gerais", "PA": "Pará", "PB": "Paraíba",
    "PR": "Paraná", "PE": "Pernambuco", "PI": "Piauí",
    "RJ": "Rio de Janeiro", "RN": "Rio Grande do Norte",
    "RS": "Rio Grande do Sul", "RO": "Rondônia", "RR": "Roraima",
    "SC": "Santa Catarina", "SP": "São Paulo", "SE": "Sergipe",
    "TO": "Tocantins"
}

# Define search terms and state codes
search_terms = [
    "sintomas dengue", "sintomas de dengue", "dengue",
    "mosquito da dengue", "febre do mosquito", "repelente contra dengue",
    "mosquito", "tratamento para dengue"
]
DEP_NAMES = {
    0: 'RO', 1: 'AC', 2: 'AM', 3: 'RR', 4: 'PA', 5: 'AP', 6: 'TO',
    7: 'MA', 8: 'PI', 9: 'CE', 10: 'RN', 11: 'PB', 12: 'PE', 
    13: 'AL', 14: 'SE', 15: 'BA', 16: 'MG', 17: 'ES', 18: 'RJ',
    19: 'SP', 20: 'PR', 21: 'SC', 22: 'RS', 23: 'MS', 24: 'MT',
    25: 'GO', 26: 'DF'
}

# Define the project path
project_path = os.getcwd()
project_path = os.path.join(project_path, "google trends", "google trends")

# Initialize counters and lists
mismatched_files = []
missing_combinations = []
all_combinations = [f"{dep}_{term}" for dep in DEP_NAMES.values() for term in search_terms]

# Process all files in the folder
files = os.listdir(project_path)
for file_name in files:
    if file_name.endswith(".csv"):
        file_path = os.path.join(project_path, file_name)
        try:
            # Load the CSV file
            df = pd.read_csv(file_path, index_col=0)
            df.reset_index(inplace=True)

            # Extract state code and category from the file name
            file_state_code, *file_category = file_name.split('.')[0].split('_')
            file_category = ' '.join(file_category)

            # Extract corresponding state name and category from the first entry
            first_entry = df.iloc[0, 1]  # Get the first value in the "Category: All categories" column
            entry_category, entry_state = first_entry.split(':', 1)
            entry_state = entry_state.strip(" ()")  # Remove parentheses and whitespace

            # Check for matches
            is_state_match = state_code_to_name.get(file_state_code) == entry_state or \
                             state_code_to_name2.get(file_state_code) == entry_state
            is_category_match = file_category.lower() == entry_category.strip().lower()

            # If overall match fails, add to the mismatched list
            if not (is_state_match and is_category_match):
                mismatched_files.append({
                    "file_name": file_name,
                    "first_entry": first_entry,
                    "state_match": is_state_match,
                    "category_match": is_category_match
                })
        except Exception as e:
            print(f"Error processing file {file_name}: {e}")

# Determine missing combinations
existing_combinations = [file_name.split('.')[0] for file_name in files if file_name.endswith(".csv")]
missing_combinations = [comb for comb in all_combinations if comb not in existing_combinations]

# Print results
print(f"\nTotal Files: {len(files)}")
print(f"Mismatched Files Count: {len(mismatched_files)}")
print("\nDetails of Mismatched Files:")
for mismatch in mismatched_files:
    print(mismatch)

print("\nMissing Combinations:")
print(missing_combinations)
len(missing_combinations)
# Out:
# Total Files: 223
# Mismatched Files Count: 111
#
# Details of Mismatched Files:
# {'file_name': 'AC_mosquito.csv', 'first_entry': 'repelente contra dengue: (State of Rio Grande do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'AC_repelente_contra_dengue.csv', 'first_entry': 'febre do mosquito: (State of Rio Grande do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'AC_tratamento_para_dengue.csv', 'first_entry': 'mosquito: (State of Rio Grande do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'AL_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (Maranhão)', 'state_match': False, 'category_match': True}
# {'file_name': 'AL_mosquito.csv', 'first_entry': 'mosquito: (Maranhão)', 'state_match': False, 'category_match': True}
# {'file_name': 'AL_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (Maranhão)', 'state_match': False, 'category_match': True}
# {'file_name': 'AL_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (Maranhão)', 'state_match': False, 'category_match': True}
# {'file_name': 'AM_mosquito.csv', 'first_entry': 'repelente contra dengue: (State of Mato Grosso do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'AM_repelente_contra_dengue.csv', 'first_entry': 'febre do mosquito: (State of Mato Grosso do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'AM_tratamento_para_dengue.csv', 'first_entry': 'mosquito: (State of Mato Grosso do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'AP_febre_do_mosquito.csv', 'first_entry': 'mosquito da dengue: (Federal District)', 'state_match': False, 'category_match': False}
# {'file_name': 'AP_mosquito.csv', 'first_entry': 'repelente contra dengue: (Federal District)', 'state_match': False, 'category_match': False}
# {'file_name': 'AP_repelente_contra_dengue.csv', 'first_entry': 'febre do mosquito: (Federal District)', 'state_match': False, 'category_match': False}
# {'file_name': 'AP_tratamento_para_dengue.csv', 'first_entry': 'mosquito: (Federal District)', 'state_match': False, 'category_match': False}
# {'file_name': 'BA_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (Ceará)', 'state_match': False, 'category_match': True}
# {'file_name': 'BA_mosquito.csv', 'first_entry': 'mosquito: (Ceará)', 'state_match': False, 'category_match': True}
# {'file_name': 'BA_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (Ceará)', 'state_match': False, 'category_match': True}
# {'file_name': 'BA_sintomas_dengue.csv', 'first_entry': 'sintomas dengue: (State of Minas Gerais)', 'state_match': False, 'category_match': True}
# {'file_name': 'BA_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (Ceará)', 'state_match': False, 'category_match': True}
# {'file_name': 'CE_febre_do_mosquito.csv', 'first_entry': 'mosquito da dengue: (State of Rio Grande do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'CE_mosquito.csv', 'first_entry': 'mosquito: (State of Roraima)', 'state_match': False, 'category_match': True}
# {'file_name': 'CE_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Roraima)', 'state_match': False, 'category_match': True}
# {'file_name': 'CE_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Roraima)', 'state_match': False, 'category_match': True}
# {'file_name': 'DF_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (Paraná)', 'state_match': False, 'category_match': True}
# {'file_name': 'DF_mosquito.csv', 'first_entry': 'mosquito: (Paraná)', 'state_match': False, 'category_match': True}
# {'file_name': 'DF_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (Paraná)', 'state_match': False, 'category_match': True}
# {'file_name': 'DF_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (Paraná)', 'state_match': False, 'category_match': True}
# {'file_name': 'ES_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (Paraíba)', 'state_match': False, 'category_match': True}
# {'file_name': 'ES_mosquito.csv', 'first_entry': 'mosquito: (Paraíba)', 'state_match': False, 'category_match': True}
# {'file_name': 'ES_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (Paraíba)', 'state_match': False, 'category_match': True}
# {'file_name': 'ES_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (Paraíba)', 'state_match': False, 'category_match': True}
# {'file_name': 'GO_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of São Paulo)', 'state_match': False, 'category_match': True}
# {'file_name': 'GO_mosquito.csv', 'first_entry': 'mosquito: (State of São Paulo)', 'state_match': False, 'category_match': True}
# {'file_name': 'GO_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of São Paulo)', 'state_match': False, 'category_match': True}
# {'file_name': 'GO_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of São Paulo)', 'state_match': False, 'category_match': True}
# {'file_name': 'MA_febre_do_mosquito.csv', 'first_entry': 'mosquito da dengue: (State of Mato Grosso)', 'state_match': False, 'category_match': False}
# {'file_name': 'MA_mosquito.csv', 'first_entry': 'mosquito: (State of Acre)', 'state_match': False, 'category_match': True}
# {'file_name': 'MA_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Acre)', 'state_match': False, 'category_match': True}
# {'file_name': 'MA_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Acre)', 'state_match': False, 'category_match': True}
# {'file_name': 'MG_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Rio Grande do Norte)', 'state_match': False, 'category_match': True}
# {'file_name': 'MG_mosquito.csv', 'first_entry': 'mosquito: (State of Rio Grande do Norte)', 'state_match': False, 'category_match': True}
# {'file_name': 'MG_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Rio Grande do Norte)', 'state_match': False, 'category_match': True}
# {'file_name': 'MG_sintomas_dengue.csv', 'first_entry': 'sintomas dengue: (State of Bahia)', 'state_match': False, 'category_match': True}
# {'file_name': 'MG_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Rio Grande do Norte)', 'state_match': False, 'category_match': True}
# {'file_name': 'MS_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Espírito Santo)', 'state_match': False, 'category_match': True}
# {'file_name': 'MS_mosquito.csv', 'first_entry': 'mosquito: (State of Espírito Santo)', 'state_match': False, 'category_match': True}
# {'file_name': 'MS_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Espírito Santo)', 'state_match': False, 'category_match': True}
# {'file_name': 'MS_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Espírito Santo)', 'state_match': False, 'category_match': True}
# {'file_name': 'MT_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Rio de Janeiro)', 'state_match': False, 'category_match': True}
# {'file_name': 'MT_mosquito.csv', 'first_entry': 'mosquito: (State of Rio de Janeiro)', 'state_match': False, 'category_match': True}
# {'file_name': 'MT_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Rio de Janeiro)', 'state_match': False, 'category_match': True}
# {'file_name': 'MT_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Rio de Janeiro)', 'state_match': False, 'category_match': True}
# {'file_name': 'multiTimeline (217).csv', 'first_entry': 'tratamento para dengue: (State of Santa Catarina)', 'state_match': False, 'category_match': False}
# {'file_name': 'multiTimeline (218).csv', 'first_entry': 'tratamento para dengue: (State of Rio Grande do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'multiTimeline (219).csv', 'first_entry': 'tratamento para dengue: (State of Mato Grosso do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'multiTimeline (220).csv', 'first_entry': 'tratamento para dengue: (State of Mato Grosso)', 'state_match': False, 'category_match': False}
# {'file_name': 'multiTimeline (221).csv', 'first_entry': 'tratamento para dengue: (State of Goiás)', 'state_match': False, 'category_match': False}
# {'file_name': 'multiTimeline (222).csv', 'first_entry': 'tratamento para dengue: (Federal District)', 'state_match': False, 'category_match': False}
# {'file_name': 'PA_mosquito.csv', 'first_entry': 'repelente contra dengue: (State of Goiás)', 'state_match': False, 'category_match': False}
# {'file_name': 'PA_repelente_contra_dengue.csv', 'first_entry': 'febre do mosquito: (State of Goiás)', 'state_match': False, 'category_match': False}
# {'file_name': 'PA_tratamento_para_dengue.csv', 'first_entry': 'mosquito: (State of Goiás)', 'state_match': False, 'category_match': False}
# {'file_name': 'PB_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Amapá)', 'state_match': False, 'category_match': True}
# {'file_name': 'PB_mosquito.csv', 'first_entry': 'mosquito: (State of Amapá)', 'state_match': False, 'category_match': True}
# {'file_name': 'PB_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Amapá)', 'state_match': False, 'category_match': True}
# {'file_name': 'PB_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Amapá)', 'state_match': False, 'category_match': True}
# {'file_name': 'PE_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Tocantins)', 'state_match': False, 'category_match': True}
# {'file_name': 'PE_mosquito.csv', 'first_entry': 'mosquito: (State of Tocantins)', 'state_match': False, 'category_match': True}
# {'file_name': 'PE_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Tocantins)', 'state_match': False, 'category_match': True}
# {'file_name': 'PE_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Tocantins)', 'state_match': False, 'category_match': True}
# {'file_name': 'PI_febre_do_mosquito.csv', 'first_entry': 'mosquito da dengue: (State of Mato Grosso do Sul)', 'state_match': False, 'category_match': False}
# {'file_name': 'PI_mosquito.csv', 'first_entry': 'mosquito: (State of Amazonas)', 'state_match': False, 'category_match': True}
# {'file_name': 'PI_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Amazonas)', 'state_match': False, 'category_match': True}
# {'file_name': 'PI_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Amazonas)', 'state_match': False, 'category_match': True}
# {'file_name': 'PR_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Sergipe)', 'state_match': False, 'category_match': True}
# {'file_name': 'PR_mosquito.csv', 'first_entry': 'mosquito: (State of Sergipe)', 'state_match': False, 'category_match': True}
# {'file_name': 'PR_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Sergipe)', 'state_match': False, 'category_match': True}
# {'file_name': 'PR_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Sergipe)', 'state_match': False, 'category_match': True}
# {'file_name': 'RJ_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Pernambuco)', 'state_match': False, 'category_match': True}
# {'file_name': 'RJ_mosquito.csv', 'first_entry': 'mosquito: (State of Pernambuco)', 'state_match': False, 'category_match': True}
# {'file_name': 'RJ_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Pernambuco)', 'state_match': False, 'category_match': True}
# {'file_name': 'RJ_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Pernambuco)', 'state_match': False, 'category_match': True}
# {'file_name': 'RN_febre_do_mosquito.csv', 'first_entry': 'mosquito da dengue: (State of Santa Catarina)', 'state_match': False, 'category_match': False}
# {'file_name': 'RN_mosquito.csv', 'first_entry': 'mosquito: (State of Pará)', 'state_match': False, 'category_match': True}
# {'file_name': 'RN_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Pará)', 'state_match': False, 'category_match': True}
# {'file_name': 'RN_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Pará)', 'state_match': False, 'category_match': True}
# {'file_name': 'RO_mosquito.csv', 'first_entry': 'repelente contra dengue: (State of Santa Catarina)', 'state_match': False, 'category_match': False}
# {'file_name': 'RO_repelente_contra_dengue.csv', 'first_entry': 'febre do mosquito: (State of Santa Catarina)', 'state_match': False, 'category_match': False}
# {'file_name': 'RO_tratamento_para_dengue.csv', 'first_entry': 'mosquito: (State of Santa Catarina)', 'state_match': False, 'category_match': False}
# {'file_name': 'RR_mosquito.csv', 'first_entry': 'repelente contra dengue: (State of Mato Grosso)', 'state_match': False, 'category_match': False}
# {'file_name': 'RR_repelente_contra_dengue.csv', 'first_entry': 'febre do mosquito: (State of Mato Grosso)', 'state_match': False, 'category_match': False}
# {'file_name': 'RR_tratamento_para_dengue.csv', 'first_entry': 'mosquito: (State of Mato Grosso)', 'state_match': False, 'category_match': False}
# {'file_name': 'RS_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Minas Gerais)', 'state_match': False, 'category_match': True}
# {'file_name': 'RS_mosquito.csv', 'first_entry': 'mosquito: (State of Minas Gerais)', 'state_match': False, 'category_match': True}
# {'file_name': 'RS_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Minas Gerais)', 'state_match': False, 'category_match': True}
# {'file_name': 'RS_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Minas Gerais)', 'state_match': False, 'category_match': True}
# {'file_name': 'SC_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Bahia)', 'state_match': False, 'category_match': True}
# {'file_name': 'SC_mosquito.csv', 'first_entry': 'mosquito: (State of Bahia)', 'state_match': False, 'category_match': True}
# {'file_name': 'SC_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Bahia)', 'state_match': False, 'category_match': True}
# {'file_name': 'SC_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Bahia)', 'state_match': False, 'category_match': True}
# {'file_name': 'SE_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (Piauí)', 'state_match': False, 'category_match': True}
# {'file_name': 'SE_mosquito.csv', 'first_entry': 'mosquito: (Piauí)', 'state_match': False, 'category_match': True}
# {'file_name': 'SE_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (Piauí)', 'state_match': False, 'category_match': True}
# {'file_name': 'SE_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (Piauí)', 'state_match': False, 'category_match': True}
# {'file_name': 'SP_febre_do_mosquito.csv', 'first_entry': 'febre do mosquito: (State of Alagoas)', 'state_match': False, 'category_match': True}
# {'file_name': 'SP_mosquito.csv', 'first_entry': 'mosquito: (State of Alagoas)', 'state_match': False, 'category_match': True}
# {'file_name': 'SP_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Alagoas)', 'state_match': False, 'category_match': True}
# {'file_name': 'SP_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Alagoas)', 'state_match': False, 'category_match': True}
# {'file_name': 'TO_febre_do_mosquito.csv', 'first_entry': 'mosquito da dengue: (State of Goiás)', 'state_match': False, 'category_match': False}
# {'file_name': 'TO_mosquito.csv', 'first_entry': 'mosquito: (State of Rondônia)', 'state_match': False, 'category_match': True}
# {'file_name': 'TO_repelente_contra_dengue.csv', 'first_entry': 'repelente contra dengue: (State of Rondônia)', 'state_match': False, 'category_match': True}
# {'file_name': 'TO_tratamento_para_dengue.csv', 'first_entry': 'tratamento para dengue: (State of Rondônia)', 'state_match': False, 'category_match': True}
#
# Missing Combinations:
# ['RO_sintomas dengue', 'RO_sintomas de dengue', 'RO_mosquito da dengue', 'RO_febre do mosquito', 'RO_repelente contra dengue', 'RO_tratamento para dengue', 'AC_sintomas dengue', 'AC_sintomas de dengue', 'AC_mosquito da dengue', 'AC_febre do mosquito', 'AC_repelente contra dengue', 'AC_tratamento para dengue', 'AM_sintomas dengue', 'AM_sintomas de dengue', 'AM_mosquito da dengue', 'AM_febre do mosquito', 'AM_repelente contra dengue', 'AM_tratamento para dengue', 'RR_sintomas dengue', 'RR_sintomas de dengue', 'RR_mosquito da dengue', 'RR_febre do mosquito', 'RR_repelente contra dengue', 'RR_tratamento para dengue', 'PA_sintomas dengue', 'PA_sintomas de dengue', 'PA_mosquito da dengue', 'PA_febre do mosquito', 'PA_repelente contra dengue', 'PA_tratamento para dengue', 'AP_sintomas dengue', 'AP_sintomas de dengue', 'AP_mosquito da dengue', 'AP_febre do mosquito', 'AP_repelente contra dengue', 'AP_tratamento para dengue', 'TO_sintomas dengue', 'TO_sintomas de dengue', 'TO_mosquito da dengue', 'TO_febre do mosquito', 'TO_repelente contra dengue', 'TO_tratamento para dengue', 'MA_sintomas dengue', 'MA_sintomas de dengue', 'MA_mosquito da dengue', 'MA_febre do mosquito', 'MA_repelente contra dengue', 'MA_tratamento para dengue', 'PI_sintomas dengue', 'PI_sintomas de dengue', 'PI_mosquito da dengue', 'PI_febre do mosquito', 'PI_repelente contra dengue', 'PI_tratamento para dengue', 'CE_sintomas dengue', 'CE_sintomas de dengue', 'CE_mosquito da dengue', 'CE_febre do mosquito', 'CE_repelente contra dengue', 'CE_tratamento para dengue', 'RN_sintomas dengue', 'RN_sintomas de dengue', 'RN_mosquito da dengue', 'RN_febre do mosquito', 'RN_repelente contra dengue', 'RN_tratamento para dengue', 'PB_sintomas dengue', 'PB_sintomas de dengue', 'PB_mosquito da dengue', 'PB_febre do mosquito', 'PB_repelente contra dengue', 'PB_tratamento para dengue', 'PE_sintomas dengue', 'PE_sintomas de dengue', 'PE_mosquito da dengue', 'PE_febre do mosquito', 'PE_repelente contra dengue', 'PE_tratamento para dengue', 'AL_sintomas dengue', 'AL_sintomas de dengue', 'AL_mosquito da dengue', 'AL_febre do mosquito', 'AL_repelente contra dengue', 'AL_tratamento para dengue', 'SE_sintomas dengue', 'SE_sintomas de dengue', 'SE_mosquito da dengue', 'SE_febre do mosquito', 'SE_repelente contra dengue', 'SE_tratamento para dengue', 'BA_sintomas dengue', 'BA_sintomas de dengue', 'BA_mosquito da dengue', 'BA_febre do mosquito', 'BA_repelente contra dengue', 'BA_tratamento para dengue', 'MG_sintomas dengue', 'MG_sintomas de dengue', 'MG_mosquito da dengue', 'MG_febre do mosquito', 'MG_repelente contra dengue', 'MG_tratamento para dengue', 'ES_sintomas dengue', 'ES_sintomas de dengue', 'ES_mosquito da dengue', 'ES_febre do mosquito', 'ES_repelente contra dengue', 'ES_tratamento para dengue', 'RJ_sintomas dengue', 'RJ_sintomas de dengue', 'RJ_mosquito da dengue', 'RJ_febre do mosquito', 'RJ_repelente contra dengue', 'RJ_tratamento para dengue', 'SP_sintomas dengue', 'SP_sintomas de dengue', 'SP_mosquito da dengue', 'SP_febre do mosquito', 'SP_repelente contra dengue', 'SP_tratamento para dengue', 'PR_sintomas dengue', 'PR_sintomas de dengue', 'PR_mosquito da dengue', 'PR_febre do mosquito', 'PR_repelente contra dengue', 'PR_tratamento para dengue', 'SC_sintomas dengue', 'SC_sintomas de dengue', 'SC_mosquito da dengue', 'SC_febre do mosquito', 'SC_repelente contra dengue', 'SC_tratamento para dengue', 'RS_sintomas dengue', 'RS_sintomas de dengue', 'RS_mosquito da dengue', 'RS_febre do mosquito', 'RS_repelente contra dengue', 'RS_tratamento para dengue', 'MS_sintomas dengue', 'MS_sintomas de dengue', 'MS_mosquito da dengue', 'MS_febre do mosquito', 'MS_repelente contra dengue', 'MS_tratamento para dengue', 'MT_sintomas dengue', 'MT_sintomas de dengue', 'MT_mosquito da dengue', 'MT_febre do mosquito', 'MT_repelente contra dengue', 'MT_tratamento para dengue', 'GO_sintomas dengue', 'GO_sintomas de dengue', 'GO_mosquito da dengue', 'GO_febre do mosquito', 'GO_repelente contra dengue' ...
# 162

# %%
from serpapi import GoogleSearch
import csv
import json

# Constants
state_code = "RO"  # Rondônia
search_term = "sintomas dengue"
timeframe = "2001-01-01 2019-12-01"  # Expanded timeframe
api_key = "35ae1bf2e3ed082a414e6351462f2cbf838ba4848a9758e14c4d475ca1bc2166"

# Output file for the test
output_file = "test_RO_sintomas_dengue.csv"

# Parameters for the SerpAPI request
params = {
    "engine": "google_trends",
    "q": search_term,
    "geo": f"BR-{state_code}",
    "hl": "pt",  # Portuguese for Brazil
    "date": timeframe,  # Adjusted key to match the parameter naming
    "api_key": api_key
}

# Fetch data from SerpAPI
try:
    print(f"Fetching data for State: {state_code}, Search Term: {search_term}")
    search = GoogleSearch(params)
    result = search.get_dict()  # Convert response to a dictionary

    # Debugging: Print the raw response to understand its structure
    print("Response received:")
    print(json.dumps(result, indent=4, ensure_ascii=False))

    # Extract interest over time data
    interest_data = result.get("interest_over_time", {}).get("timeline_data", [])
    
    if interest_data:
        # Save results to a CSV file
        with open(output_file, mode="w", newline="", encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow(["Date", "Interest"])
            
            for entry in interest_data:
                date = entry.get("date")
                values = entry.get("values", [])
                partial_data = entry.get("partial_data", False)
                
                # Only process non-partial weeks with valid values
                if not partial_data and values:
                    interest_value = values[0].get("value", 0)
                    writer.writerow([date, interest_value])
        
        print(f"Data saved to {output_file}")
    else:
        print("No data found for the specified query. Check if the term or geo is valid.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
earch_terms = [
    "sintomas dengue", "sintomas de dengue", "dengue",
    "mosquito da dengue", "febre do mosquito", "repelente contra dengue",
    "mosquito", "tratamento para dengue"
]
DEP_NAMES = {
    0: 'RO', 1: 'AC', 2: 'AM', 3: 'RR', 4: 'PA', 5: 'AP', 6: 'TO',
    7: 'MA', 8: 'PI', 9: 'CE', 10: 'RN', 11: 'PB', 
    # 12: 'PE', 
    # 13: 'AL', 14: 'SE', 15: 'BA', 16: 'MG', 17: 'ES', 18: 'RJ',
    # 19: 'SP', 20: 'PR', 21: 'SC', 22: 'RS', 23: 'MS', 24: 'MT',
    # 25: 'GO', 26: 'DF'
}

# %%
import os
import csv
import json
from serpapi import GoogleSearch

# Constants
search_terms = [
    "sintomas dengue", "sintomas de dengue", "dengue",
    "mosquito da dengue", "febre do mosquito", "repelente contra dengue",
    "mosquito", "tratamento para dengue"
]
DEP_NAMES = {
    0: 'RO', 1: 'AC', 2: 'AM', 3: 'RR', 4: 'PA', 5: 'AP', 6: 'TO',
    7: 'MA', 8: 'PI', 9: 'CE', 10: 'RN', 11: 'PB'
}
timeframe = "2001-01-01 2019-12-01"  # Expanded timeframe
api_key = "35ae1bf2e3ed082a414e6351462f2cbf838ba4848a9758e14c4d475ca1bc2166"

# Create a folder to save results
output_folder = "serpapi_results"
os.makedirs(output_folder, exist_ok=True)

# Initialize a list to track missing data combinations
missing_data_combinations = []

# Process each state and each search term
for state_code in DEP_NAMES.values():
    for search_term in search_terms:
        # Parameters for the SerpAPI request
        params = {
            "engine": "google_trends",
            "q": search_term,
            "geo": f"BR-{state_code}",
            "hl": "pt",  # Portuguese for Brazil
            "date": timeframe,
            "api_key": api_key
        }

        # Output file path
        output_file = os.path.join(output_folder, f"{state_code}_{search_term.replace(' ', '_')}.csv")

        # Fetch data from SerpAPI
        try:
            print(f"Fetching data for State: {state_code}, Search Term: {search_term}")
            search = GoogleSearch(params)
            result = search.get_dict()  # Convert response to a dictionary

            # Debugging: Print the raw response to understand its structure
            print("Response received:")
            # print(json.dumps(result, indent=4, ensure_ascii=False))

            # Extract interest over time data
            interest_data = result.get("interest_over_time", {}).get("timeline_data", [])
            
            if interest_data:
                # Save results to a CSV file
                with open(output_file, mode="w", newline="", encoding="utf-8") as file:
                    writer = csv.writer(file)
                    writer.writerow(["Date", "Interest"])
                    
                    for entry in interest_data:
                        date = entry.get("date")
                        values = entry.get("values", [])
                        partial_data = entry.get("partial_data", False)
                        
                        # Only process non-partial weeks with valid values
                        if not partial_data and values:
                            interest_value = values[0].get("value", 0)
                            writer.writerow([date, interest_value])
                
                print(f"Data saved to {output_file}")
            else:
                print(f"No data found for State: {state_code}, Search Term: {search_term}")
                missing_data_combinations.append((state_code, search_term))
        except Exception as e:
            print(f"An error occurred for State: {state_code}, Search Term: {search_term}: {e}")
            missing_data_combinations.append((state_code, search_term))

# Log missing data combinations
if missing_data_combinations:
    missing_file = os.path.join(output_folder, "missing_data_log.txt")
    with open(missing_file, "w", encoding="utf-8") as log_file:
        log_file.write("No data found for the following State-Search Term combinations:\n")
        for state, term in missing_data_combinations:
            log_file.write(f"State: {state}, Search Term: {term}\n")
    print(f"Missing data logged to {missing_file}")
else:
    print("All data successfully fetched and saved.")
# Out:
# Fetching data for State: RO, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\RO_sintomas_dengue.csv
# Fetching data for State: RO, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\RO_sintomas_de_dengue.csv
# Fetching data for State: RO, Search Term: dengue
# Response received:
# Data saved to serpapi_results\RO_dengue.csv
# Fetching data for State: RO, Search Term: mosquito da dengue
# Response received:
# No data found for State: RO, Search Term: mosquito da dengue
# Fetching data for State: RO, Search Term: febre do mosquito
# Response received:
# No data found for State: RO, Search Term: febre do mosquito
# Fetching data for State: RO, Search Term: repelente contra dengue
# Response received:
# No data found for State: RO, Search Term: repelente contra dengue
# Fetching data for State: RO, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\RO_mosquito.csv
# Fetching data for State: RO, Search Term: tratamento para dengue
# Response received:
# No data found for State: RO, Search Term: tratamento para dengue
# Fetching data for State: AC, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\AC_sintomas_dengue.csv
# Fetching data for State: AC, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\AC_sintomas_de_dengue.csv
# Fetching data for State: AC, Search Term: dengue
# Response received:
# Data saved to serpapi_results\AC_dengue.csv
# Fetching data for State: AC, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\AC_mosquito_da_dengue.csv
# Fetching data for State: AC, Search Term: febre do mosquito
# Response received:
# No data found for State: AC, Search Term: febre do mosquito
# Fetching data for State: AC, Search Term: repelente contra dengue
# Response received:
# No data found for State: AC, Search Term: repelente contra dengue
# Fetching data for State: AC, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\AC_mosquito.csv
# Fetching data for State: AC, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\AC_tratamento_para_dengue.csv
# Fetching data for State: AM, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\AM_sintomas_dengue.csv
# Fetching data for State: AM, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\AM_sintomas_de_dengue.csv
# Fetching data for State: AM, Search Term: dengue
# Response received:
# Data saved to serpapi_results\AM_dengue.csv
# Fetching data for State: AM, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\AM_mosquito_da_dengue.csv
# Fetching data for State: AM, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\AM_febre_do_mosquito.csv
# Fetching data for State: AM, Search Term: repelente contra dengue
# Response received:
# No data found for State: AM, Search Term: repelente contra dengue
# Fetching data for State: AM, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\AM_mosquito.csv
# Fetching data for State: AM, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\AM_tratamento_para_dengue.csv
# Fetching data for State: RR, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\RR_sintomas_dengue.csv
# Fetching data for State: RR, Search Term: sintomas de dengue
# Response received:
# No data found for State: RR, Search Term: sintomas de dengue
# Fetching data for State: RR, Search Term: dengue
# Response received:
# Data saved to serpapi_results\RR_dengue.csv
# Fetching data for State: RR, Search Term: mosquito da dengue
# Response received:
# No data found for State: RR, Search Term: mosquito da dengue
# Fetching data for State: RR, Search Term: febre do mosquito
# Response received:
# No data found for State: RR, Search Term: febre do mosquito
# Fetching data for State: RR, Search Term: repelente contra dengue
# Response received:
# No data found for State: RR, Search Term: repelente contra dengue
# Fetching data for State: RR, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\RR_mosquito.csv
# Fetching data for State: RR, Search Term: tratamento para dengue
# Response received:
# No data found for State: RR, Search Term: tratamento para dengue
# Fetching data for State: PA, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\PA_sintomas_dengue.csv
# Fetching data for State: PA, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\PA_sintomas_de_dengue.csv
# Fetching data for State: PA, Search Term: dengue
# Response received:
# Data saved to serpapi_results\PA_dengue.csv
# Fetching data for State: PA, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\PA_mosquito_da_dengue.csv
# Fetching data for State: PA, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\PA_febre_do_mosquito.csv
# Fetching data for State: PA, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\PA_repelente_contra_dengue.csv
# Fetching data for State: PA, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\PA_mosquito.csv
# Fetching data for State: PA, Search Term: tratamento para dengue
# Response received:
# No data found for State: PA, Search Term: tratamento para dengue
# Fetching data for State: AP, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\AP_sintomas_dengue.csv
# Fetching data for State: AP, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\AP_sintomas_de_dengue.csv
# Fetching data for State: AP, Search Term: dengue
# Response received:
# Data saved to serpapi_results\AP_dengue.csv
# Fetching data for State: AP, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\AP_mosquito_da_dengue.csv
# Fetching data for State: AP, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\AP_febre_do_mosquito.csv
# Fetching data for State: AP, Search Term: repelente contra dengue
# Response received:
# No data found for State: AP, Search Term: repelente contra dengue
# Fetching data for State: AP, Search Term: mosquito
# Response received:
# No data found for State: AP, Search Term: mosquito
# Fetching data for State: AP, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\AP_tratamento_para_dengue.csv
# Fetching data for State: TO, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\TO_sintomas_dengue.csv
# Fetching data for State: TO, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\TO_sintomas_de_dengue.csv
# Fetching data for State: TO, Search Term: dengue
# Response received:
# Data saved to serpapi_results\TO_dengue.csv
# Fetching data for State: TO, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\TO_mosquito_da_dengue.csv
# Fetching data for State: TO, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\TO_febre_do_mosquito.csv
# Fetching data for State: TO, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\TO_repelente_contra_dengue.csv
# Fetching data for State: TO, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\TO_mosquito.csv
# Fetching data for State: TO, Search Term: tratamento para dengue
# Response received:
# No data found for State: TO, Search Term: tratamento para dengue
# Fetching data for State: MA, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\MA_sintomas_dengue.csv
# Fetching data for State: MA, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\MA_sintomas_de_dengue.csv
# Fetching data for State: MA, Search Term: dengue
# Response received:
# Data saved to serpapi_results\MA_dengue.csv
# Fetching data for State: MA, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\MA_mosquito_da_dengue.csv
# Fetching data for State: MA, Search Term: febre do mosquito
# Response received:
# No data found for State: MA, Search Term: febre do mosquito
# Fetching data for State: MA, Search Term: repelente contra dengue
# Response received:
# No data found for State: MA, Search Term: repelente contra dengue
# Fetching data for State: MA, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\MA_mosquito.csv
# Fetching data for State: MA, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\MA_tratamento_para_dengue.csv
# Fetching data for State: PI, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\PI_sintomas_dengue.csv
# Fetching data for State: PI, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\PI_sintomas_de_dengue.csv
# Fetching data for State: PI, Search Term: dengue
# Response received:
# Data saved to serpapi_results\PI_dengue.csv
# Fetching data for State: PI, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\PI_mosquito_da_dengue.csv
# Fetching data for State: PI, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\PI_febre_do_mosquito.csv
# Fetching data for State: PI, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\PI_repelente_contra_dengue.csv
# Fetching data for State: PI, Search Term: mosquito
# Response received:
# No data found for State: PI, Search Term: mosquito
# Fetching data for State: PI, Search Term: tratamento para dengue
# Response received:
# No data found for State: PI, Search Term: tratamento para dengue
# Fetching data for State: CE, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\CE_sintomas_dengue.csv
# Fetching data for State: CE, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\CE_sintomas_de_dengue.csv
# Fetching data for State: CE, Search Term: dengue
# Response received:
# Data saved to serpapi_results\CE_dengue.csv
# Fetching data for State: CE, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\CE_mosquito_da_dengue.csv
# Fetching data for State: CE, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\CE_febre_do_mosquito.csv
# Fetching data for State: CE, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\CE_repelente_contra_dengue.csv
# Fetching data for State: CE, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\CE_mosquito.csv
# Fetching data for State: CE, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\CE_tratamento_para_dengue.csv
# Fetching data for State: RN, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\RN_sintomas_dengue.csv
# Fetching data for State: RN, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\RN_sintomas_de_dengue.csv
# Fetching data for State: RN, Search Term: dengue
# Response received:
# Data saved to serpapi_results\RN_dengue.csv
# Fetching data for State: RN, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\RN_mosquito_da_dengue.csv
# Fetching data for State: RN, Search Term: febre do mosquito
# Response received:
# No data found for State: RN, Search Term: febre do mosquito
# Fetching data for State: RN, Search Term: repelente contra dengue
# Response received:
# No data found for State: RN, Search Term: repelente contra dengue
# Fetching data for State: RN, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\RN_mosquito.csv
# Fetching data for State: RN, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\RN_tratamento_para_dengue.csv
# Fetching data for State: PB, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\PB_sintomas_dengue.csv
# Fetching data for State: PB, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\PB_sintomas_de_dengue.csv
# Fetching data for State: PB, Search Term: dengue
# Response received:
# Data saved to serpapi_results\PB_dengue.csv
# Fetching data for State: PB, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\PB_mosquito_da_dengue.csv
# Fetching data for State: PB, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\PB_febre_do_mosquito.csv
# Fetching data for State: PB, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\PB_repelente_contra_dengue.csv
# Fetching data for State: PB, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\PB_mosquito.csv
# Fetching data for State: PB, Search Term: tratamento para dengue
# Response received:
# No data found for State: PB, Search Term: tratamento para dengue
# Missing data logged to serpapi_results\missing_data_log.txt

# %%
import os
import csv
import json
from serpapi import GoogleSearch

# Constants
search_terms = [
    "sintomas dengue", "sintomas de dengue", "dengue",
    "mosquito da dengue", "febre do mosquito", "repelente contra dengue",
    "mosquito", "tratamento para dengue"
]
DEP_NAMES = {
    12: 'PE', 13: 'AL', 14: 'SE', 15: 'BA', 16: 'MG', 17: 'ES', 18: 'RJ',
    19: 'SP', 20: 'PR', 21: 'SC', 22: 'RS'
}


timeframe = "2001-01-01 2019-12-01"  # Expanded timeframe
api_key = "0bbeb515833bea08369ee736c9cfba648cea12fea30afacc28238b78e30382e5"

# Create a folder to save results
output_folder = "serpapi_results"
os.makedirs(output_folder, exist_ok=True)

# Initialize a list to track missing data combinations
missing_data_combinations = []

# Process each state and each search term
for state_code in DEP_NAMES.values():
    for search_term in search_terms:
        # Parameters for the SerpAPI request
        params = {
            "engine": "google_trends",
            "q": search_term,
            "geo": f"BR-{state_code}",
            "hl": "pt",  # Portuguese for Brazil
            "date": timeframe,
            "api_key": api_key
        }

        # Output file path
        output_file = os.path.join(output_folder, f"{state_code}_{search_term.replace(' ', '_')}.csv")

        # Fetch data from SerpAPI
        try:
            print(f"Fetching data for State: {state_code}, Search Term: {search_term}")
            search = GoogleSearch(params)
            result = search.get_dict()  # Convert response to a dictionary

            # Debugging: Print the raw response to understand its structure
            print("Response received:")
            # print(json.dumps(result, indent=4, ensure_ascii=False))

            # Extract interest over time data
            interest_data = result.get("interest_over_time", {}).get("timeline_data", [])
            
            if interest_data:
                # Save results to a CSV file
                with open(output_file, mode="w", newline="", encoding="utf-8") as file:
                    writer = csv.writer(file)
                    writer.writerow(["Date", "Interest"])
                    
                    for entry in interest_data:
                        date = entry.get("date")
                        values = entry.get("values", [])
                        partial_data = entry.get("partial_data", False)
                        
                        # Only process non-partial weeks with valid values
                        if not partial_data and values:
                            interest_value = values[0].get("value", 0)
                            writer.writerow([date, interest_value])
                
                print(f"Data saved to {output_file}")
            else:
                print(f"No data found for State: {state_code}, Search Term: {search_term}")
                missing_data_combinations.append((state_code, search_term))
        except Exception as e:
            print(f"An error occurred for State: {state_code}, Search Term: {search_term}: {e}")
            missing_data_combinations.append((state_code, search_term))

# Log missing data combinations
if missing_data_combinations:
    missing_file = os.path.join(output_folder, "missing_data_log.txt")
    with open(missing_file, "w", encoding="utf-8") as log_file:
        log_file.write("No data found for the following State-Search Term combinations:\n")
        for state, term in missing_data_combinations:
            log_file.write(f"State: {state}, Search Term: {term}\n")
    print(f"Missing data logged to {missing_file}")
else:
    print("All data successfully fetched and saved.")
# Out:
# Fetching data for State: PE, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\PE_sintomas_dengue.csv
# Fetching data for State: PE, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\PE_sintomas_de_dengue.csv
# Fetching data for State: PE, Search Term: dengue
# Response received:
# Data saved to serpapi_results\PE_dengue.csv
# Fetching data for State: PE, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\PE_mosquito_da_dengue.csv
# Fetching data for State: PE, Search Term: febre do mosquito
# Response received:
# No data found for State: PE, Search Term: febre do mosquito
# Fetching data for State: PE, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\PE_repelente_contra_dengue.csv
# Fetching data for State: PE, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\PE_mosquito.csv
# Fetching data for State: PE, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\PE_tratamento_para_dengue.csv
# Fetching data for State: AL, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\AL_sintomas_dengue.csv
# Fetching data for State: AL, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\AL_sintomas_de_dengue.csv
# Fetching data for State: AL, Search Term: dengue
# Response received:
# Data saved to serpapi_results\AL_dengue.csv
# Fetching data for State: AL, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\AL_mosquito_da_dengue.csv
# Fetching data for State: AL, Search Term: febre do mosquito
# Response received:
# No data found for State: AL, Search Term: febre do mosquito
# Fetching data for State: AL, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\AL_repelente_contra_dengue.csv
# Fetching data for State: AL, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\AL_mosquito.csv
# Fetching data for State: AL, Search Term: tratamento para dengue
# Response received:
# No data found for State: AL, Search Term: tratamento para dengue
# Fetching data for State: SE, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\SE_sintomas_dengue.csv
# Fetching data for State: SE, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\SE_sintomas_de_dengue.csv
# Fetching data for State: SE, Search Term: dengue
# Response received:
# Data saved to serpapi_results\SE_dengue.csv
# Fetching data for State: SE, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\SE_mosquito_da_dengue.csv
# Fetching data for State: SE, Search Term: febre do mosquito
# Response received:
# No data found for State: SE, Search Term: febre do mosquito
# Fetching data for State: SE, Search Term: repelente contra dengue
# Response received:
# No data found for State: SE, Search Term: repelente contra dengue
# Fetching data for State: SE, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\SE_mosquito.csv
# Fetching data for State: SE, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\SE_tratamento_para_dengue.csv
# Fetching data for State: BA, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\BA_sintomas_dengue.csv
# Fetching data for State: BA, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\BA_sintomas_de_dengue.csv
# Fetching data for State: BA, Search Term: dengue
# Response received:
# Data saved to serpapi_results\BA_dengue.csv
# Fetching data for State: BA, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\BA_mosquito_da_dengue.csv
# Fetching data for State: BA, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\BA_febre_do_mosquito.csv
# Fetching data for State: BA, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\BA_repelente_contra_dengue.csv
# Fetching data for State: BA, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\BA_mosquito.csv
# Fetching data for State: BA, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\BA_tratamento_para_dengue.csv
# Fetching data for State: MG, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\MG_sintomas_dengue.csv
# Fetching data for State: MG, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\MG_sintomas_de_dengue.csv
# Fetching data for State: MG, Search Term: dengue
# Response received:
# Data saved to serpapi_results\MG_dengue.csv
# Fetching data for State: MG, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\MG_mosquito_da_dengue.csv
# Fetching data for State: MG, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\MG_febre_do_mosquito.csv
# Fetching data for State: MG, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\MG_repelente_contra_dengue.csv
# Fetching data for State: MG, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\MG_mosquito.csv
# Fetching data for State: MG, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\MG_tratamento_para_dengue.csv
# Fetching data for State: ES, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\ES_sintomas_dengue.csv
# Fetching data for State: ES, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\ES_sintomas_de_dengue.csv
# Fetching data for State: ES, Search Term: dengue
# Response received:
# Data saved to serpapi_results\ES_dengue.csv
# Fetching data for State: ES, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\ES_mosquito_da_dengue.csv
# Fetching data for State: ES, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\ES_febre_do_mosquito.csv
# Fetching data for State: ES, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\ES_repelente_contra_dengue.csv
# Fetching data for State: ES, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\ES_mosquito.csv
# Fetching data for State: ES, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\ES_tratamento_para_dengue.csv
# Fetching data for State: RJ, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\RJ_sintomas_dengue.csv
# Fetching data for State: RJ, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\RJ_sintomas_de_dengue.csv
# Fetching data for State: RJ, Search Term: dengue
# Response received:
# Data saved to serpapi_results\RJ_dengue.csv
# Fetching data for State: RJ, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\RJ_mosquito_da_dengue.csv
# Fetching data for State: RJ, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\RJ_febre_do_mosquito.csv
# Fetching data for State: RJ, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\RJ_repelente_contra_dengue.csv
# Fetching data for State: RJ, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\RJ_mosquito.csv
# Fetching data for State: RJ, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\RJ_tratamento_para_dengue.csv
# Fetching data for State: SP, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\SP_sintomas_dengue.csv
# Fetching data for State: SP, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\SP_sintomas_de_dengue.csv
# Fetching data for State: SP, Search Term: dengue
# Response received:
# Data saved to serpapi_results\SP_dengue.csv
# Fetching data for State: SP, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\SP_mosquito_da_dengue.csv
# Fetching data for State: SP, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\SP_febre_do_mosquito.csv
# Fetching data for State: SP, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\SP_repelente_contra_dengue.csv
# Fetching data for State: SP, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\SP_mosquito.csv
# Fetching data for State: SP, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\SP_tratamento_para_dengue.csv
# Fetching data for State: PR, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\PR_sintomas_dengue.csv
# Fetching data for State: PR, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\PR_sintomas_de_dengue.csv
# Fetching data for State: PR, Search Term: dengue
# Response received:
# Data saved to serpapi_results\PR_dengue.csv
# Fetching data for State: PR, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\PR_mosquito_da_dengue.csv
# Fetching data for State: PR, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\PR_febre_do_mosquito.csv
# Fetching data for State: PR, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\PR_repelente_contra_dengue.csv
# Fetching data for State: PR, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\PR_mosquito.csv
# Fetching data for State: PR, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\PR_tratamento_para_dengue.csv
# Fetching data for State: SC, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\SC_sintomas_dengue.csv
# Fetching data for State: SC, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\SC_sintomas_de_dengue.csv
# Fetching data for State: SC, Search Term: dengue
# Response received:
# Data saved to serpapi_results\SC_dengue.csv
# Fetching data for State: SC, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\SC_mosquito_da_dengue.csv
# Fetching data for State: SC, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\SC_febre_do_mosquito.csv
# Fetching data for State: SC, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\SC_repelente_contra_dengue.csv
# Fetching data for State: SC, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\SC_mosquito.csv
# Fetching data for State: SC, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\SC_tratamento_para_dengue.csv
# Fetching data for State: RS, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\RS_sintomas_dengue.csv
# Fetching data for State: RS, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\RS_sintomas_de_dengue.csv
# Fetching data for State: RS, Search Term: dengue
# Response received:
# Data saved to serpapi_results\RS_dengue.csv
# Fetching data for State: RS, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\RS_mosquito_da_dengue.csv
# Fetching data for State: RS, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\RS_febre_do_mosquito.csv
# Fetching data for State: RS, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\RS_repelente_contra_dengue.csv
# Fetching data for State: RS, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\RS_mosquito.csv
# Fetching data for State: RS, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\RS_tratamento_para_dengue.csv
# Missing data logged to serpapi_results\missing_data_log.txt

# %%
import os
import csv
import json
from serpapi import GoogleSearch

# Constants
search_terms = [
    "sintomas dengue", "sintomas de dengue", "dengue",
    "mosquito da dengue", "febre do mosquito", "repelente contra dengue",
    "mosquito", "tratamento para dengue"
]
DEP_NAMES = {
    23: 'MS', 24: 'MT',
    25: 'GO', 26: 'DF'
}


timeframe = "2001-01-01 2019-12-01"  # Expanded timeframe
api_key = "7e8d78c24551d970db3f53487e45a82c232180250e17fab6a5eede7c3ee0c70c"

# Create a folder to save results
output_folder = "serpapi_results"
os.makedirs(output_folder, exist_ok=True)

# Initialize a list to track missing data combinations
missing_data_combinations = []

# Process each state and each search term
for state_code in DEP_NAMES.values():
    for search_term in search_terms:
        # Parameters for the SerpAPI request
        params = {
            "engine": "google_trends",
            "q": search_term,
            "geo": f"BR-{state_code}",
            "hl": "pt",  # Portuguese for Brazil
            "date": timeframe,
            "api_key": api_key
        }

        # Output file path
        output_file = os.path.join(output_folder, f"{state_code}_{search_term.replace(' ', '_')}.csv")

        # Fetch data from SerpAPI
        try:
            print(f"Fetching data for State: {state_code}, Search Term: {search_term}")
            search = GoogleSearch(params)
            result = search.get_dict()  # Convert response to a dictionary

            # Debugging: Print the raw response to understand its structure
            print("Response received:")
            # print(json.dumps(result, indent=4, ensure_ascii=False))

            # Extract interest over time data
            interest_data = result.get("interest_over_time", {}).get("timeline_data", [])
            
            if interest_data:
                # Save results to a CSV file
                with open(output_file, mode="w", newline="", encoding="utf-8") as file:
                    writer = csv.writer(file)
                    writer.writerow(["Date", "Interest"])
                    
                    for entry in interest_data:
                        date = entry.get("date")
                        values = entry.get("values", [])
                        partial_data = entry.get("partial_data", False)
                        
                        # Only process non-partial weeks with valid values
                        if not partial_data and values:
                            interest_value = values[0].get("value", 0)
                            writer.writerow([date, interest_value])
                
                print(f"Data saved to {output_file}")
            else:
                print(f"No data found for State: {state_code}, Search Term: {search_term}")
                missing_data_combinations.append((state_code, search_term))
        except Exception as e:
            print(f"An error occurred for State: {state_code}, Search Term: {search_term}: {e}")
            missing_data_combinations.append((state_code, search_term))

# Log missing data combinations
if missing_data_combinations:
    missing_file = os.path.join(output_folder, "missing_data_log.txt")
    with open(missing_file, "w", encoding="utf-8") as log_file:
        log_file.write("No data found for the following State-Search Term combinations:\n")
        for state, term in missing_data_combinations:
            log_file.write(f"State: {state}, Search Term: {term}\n")
    print(f"Missing data logged to {missing_file}")
else:
    print("All data successfully fetched and saved.")
# Out:
# Fetching data for State: MS, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\MS_sintomas_dengue.csv
# Fetching data for State: MS, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\MS_sintomas_de_dengue.csv
# Fetching data for State: MS, Search Term: dengue
# Response received:
# Data saved to serpapi_results\MS_dengue.csv
# Fetching data for State: MS, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\MS_mosquito_da_dengue.csv
# Fetching data for State: MS, Search Term: febre do mosquito
# Response received:
# No data found for State: MS, Search Term: febre do mosquito
# Fetching data for State: MS, Search Term: repelente contra dengue
# Response received:
# No data found for State: MS, Search Term: repelente contra dengue
# Fetching data for State: MS, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\MS_mosquito.csv
# Fetching data for State: MS, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\MS_tratamento_para_dengue.csv
# Fetching data for State: MT, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\MT_sintomas_dengue.csv
# Fetching data for State: MT, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\MT_sintomas_de_dengue.csv
# Fetching data for State: MT, Search Term: dengue
# Response received:
# Data saved to serpapi_results\MT_dengue.csv
# Fetching data for State: MT, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\MT_mosquito_da_dengue.csv
# Fetching data for State: MT, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\MT_febre_do_mosquito.csv
# Fetching data for State: MT, Search Term: repelente contra dengue
# Response received:
# No data found for State: MT, Search Term: repelente contra dengue
# Fetching data for State: MT, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\MT_mosquito.csv
# Fetching data for State: MT, Search Term: tratamento para dengue
# Response received:
# No data found for State: MT, Search Term: tratamento para dengue
# Fetching data for State: GO, Search Term: sintomas dengue
# Response received:
# Data saved to serpapi_results\GO_sintomas_dengue.csv
# Fetching data for State: GO, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\GO_sintomas_de_dengue.csv
# Fetching data for State: GO, Search Term: dengue
# Response received:
# Data saved to serpapi_results\GO_dengue.csv
# Fetching data for State: GO, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\GO_mosquito_da_dengue.csv
# Fetching data for State: GO, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\GO_febre_do_mosquito.csv
# Fetching data for State: GO, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\GO_repelente_contra_dengue.csv
# Fetching data for State: GO, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\GO_mosquito.csv
# Fetching data for State: GO, Search Term: tratamento para dengue
# Response received:
# No data found for State: GO, Search Term: tratamento para dengue
# Fetching data for State: DF, Search Term: sintomas dengue
# Response received:
# No data found for State: DF, Search Term: sintomas dengue
# Fetching data for State: DF, Search Term: sintomas de dengue
# Response received:
# Data saved to serpapi_results\DF_sintomas_de_dengue.csv
# Fetching data for State: DF, Search Term: dengue
# Response received:
# Data saved to serpapi_results\DF_dengue.csv
# Fetching data for State: DF, Search Term: mosquito da dengue
# Response received:
# Data saved to serpapi_results\DF_mosquito_da_dengue.csv
# Fetching data for State: DF, Search Term: febre do mosquito
# Response received:
# Data saved to serpapi_results\DF_febre_do_mosquito.csv
# Fetching data for State: DF, Search Term: repelente contra dengue
# Response received:
# Data saved to serpapi_results\DF_repelente_contra_dengue.csv
# Fetching data for State: DF, Search Term: mosquito
# Response received:
# Data saved to serpapi_results\DF_mosquito.csv
# Fetching data for State: DF, Search Term: tratamento para dengue
# Response received:
# Data saved to serpapi_results\DF_tratamento_para_dengue.csv
# Missing data logged to serpapi_results\missing_data_log.txt

# %%
# List of files to process
file_paths = ["../serpapi_results/missing_data_log.txt", "../serpapi_results/missing_data_log1.txt", "../serpapi_results/missing_data_log2.txt"]

# Dictionaries to store total frequencies
total_state_frequency = {}
total_search_term_frequency = {}
total_combination_frequency = {}

# Process each file
for file_path in file_paths:
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith("State:"):
                # Extract state and search term
                parts = line.strip().split(", ")
                state = parts[0].split(": ")[1]
                search_term = parts[1].split(": ")[1]

                # Update total frequencies for states
                total_state_frequency[state] = total_state_frequency.get(state, 0) + 1

                # Update total frequencies for search terms
                total_search_term_frequency[search_term] = total_search_term_frequency.get(search_term, 0) + 1

                # Update total frequencies for combinations
                combination = f"{state} - {search_term}"
                total_combination_frequency[combination] = total_combination_frequency.get(combination, 0) + 1

# Print the total frequencies
print("Total State Frequencies:")
for state, freq in total_state_frequency.items():
    print(f"{state}: {freq}")

print("\nTotal Search Term Frequencies:")
for search_term, freq in total_search_term_frequency.items():
    print(f"{search_term}: {freq}")

print("\nTotal State-Search Term Combination Frequencies:")
for combination, freq in total_combination_frequency.items():
    print(f"{combination}: {freq}")

print("\n")
# List of search terms to filter
filter_search_terms = {"sintomas dengue", "mosquito da dengue", "sintomas de dengue", "mosquito"}

# Filter combinations based on exact search term match
filtered_combinations = {
    combination: freq
    for combination, freq in total_combination_frequency.items()
    if combination.split(" - ")[1] in filter_search_terms  # Match exact search term
}

# Print filtered combinations
print("Filtered Combinations (Exact Search Term Matches):")
for combination, freq in filtered_combinations.items():
    print(f"{combination}: {freq}")
# Out:
# Total State Frequencies:
# MS: 2
# MT: 2
# GO: 1
# DF: 1
# RO: 4
# AC: 2
# AM: 1
# RR: 5
# PA: 1
# AP: 2
# TO: 1
# MA: 2
# PI: 2
# RN: 2
# PB: 1
# PE: 1
# AL: 2
# SE: 2
#
# Total Search Term Frequencies:
# febre do mosquito: 9
# repelente contra dengue: 10
# tratamento para dengue: 9
# sintomas dengue: 1
# mosquito da dengue: 2
# sintomas de dengue: 1
# mosquito: 2
#
# Total State-Search Term Combination Frequencies:
# MS - febre do mosquito: 1
# MS - repelente contra dengue: 1
# MT - repelente contra dengue: 1
# MT - tratamento para dengue: 1
# GO - tratamento para dengue: 1
# DF - sintomas dengue: 1
# RO - mosquito da dengue: 1
# RO - febre do mosquito: 1
# RO - repelente contra dengue: 1
# RO - tratamento para dengue: 1
# AC - febre do mosquito: 1
# AC - repelente contra dengue: 1
# AM - repelente contra dengue: 1
# RR - sintomas de dengue: 1
# RR - mosquito da dengue: 1
# RR - febre do mosquito: 1
# RR - repelente contra dengue: 1
# RR - tratamento para dengue: 1
# PA - tratamento para dengue: 1
# AP - repelente contra dengue: 1
# AP - mosquito: 1
# TO - tratamento para dengue: 1
# MA - febre do mosquito: 1
# MA - repelente contra dengue: 1
# PI - mosquito: 1
# PI - tratamento para dengue: 1
# RN - febre do mosquito: 1
# RN - repelente contra dengue: 1
# PB - tratamento para dengue: 1
# PE - febre do mosquito: 1
# AL - febre do mosquito: 1
# AL - tratamento para dengue: 1
# SE - febre do mosquito: 1
# SE - repelente contra dengue: 1
#
#
# Filtered Combinations (Exact Search Term Matches):
# DF - sintomas dengue: 1
# RO - mosquito da dengue: 1
# RR - sintomas de dengue: 1
# RR - mosquito da dengue: 1
# AP - mosquito: 1
# PI - mosquito: 1

# %%
import os
import shutil

# Constants
current_folder = "../serpapi_results"  # Replace with the folder where the files are stored
new_folder = "excluded_terms"
excluded_terms = ["febre do mosquito", "repelente contra dengue", "tratamento para dengue"]

# Create a folder for excluded terms
os.makedirs(new_folder, exist_ok=True)

# Process files in the current folder
for file_name in os.listdir(current_folder):
    # Check if the file corresponds to an excluded term
    for term in excluded_terms:
        sanitized_term = term.replace(" ", "_")
        if sanitized_term in file_name:
            # Move file to the new folder
            source_path = os.path.join(current_folder, file_name)
            destination_path = os.path.join(new_folder, file_name)
            shutil.move(source_path, destination_path)
            print(f"Moved: {file_name} -> {new_folder}")

print("File movement completed.")
# Out:
# Moved: AC_tratamento_para_dengue.csv -> excluded_terms
# Moved: AL_repelente_contra_dengue.csv -> excluded_terms
# Moved: AM_febre_do_mosquito.csv -> excluded_terms
# Moved: AM_tratamento_para_dengue.csv -> excluded_terms
# Moved: AP_febre_do_mosquito.csv -> excluded_terms
# Moved: AP_tratamento_para_dengue.csv -> excluded_terms
# Moved: BA_febre_do_mosquito.csv -> excluded_terms
# Moved: BA_repelente_contra_dengue.csv -> excluded_terms
# Moved: BA_tratamento_para_dengue.csv -> excluded_terms
# Moved: CE_febre_do_mosquito.csv -> excluded_terms
# Moved: CE_repelente_contra_dengue.csv -> excluded_terms
# Moved: CE_tratamento_para_dengue.csv -> excluded_terms
# Moved: DF_febre_do_mosquito.csv -> excluded_terms
# Moved: DF_repelente_contra_dengue.csv -> excluded_terms
# Moved: DF_tratamento_para_dengue.csv -> excluded_terms
# Moved: ES_febre_do_mosquito.csv -> excluded_terms
# Moved: ES_repelente_contra_dengue.csv -> excluded_terms
# Moved: ES_tratamento_para_dengue.csv -> excluded_terms
# Moved: GO_febre_do_mosquito.csv -> excluded_terms
# Moved: GO_repelente_contra_dengue.csv -> excluded_terms
# Moved: MA_tratamento_para_dengue.csv -> excluded_terms
# Moved: MG_febre_do_mosquito.csv -> excluded_terms
# Moved: MG_repelente_contra_dengue.csv -> excluded_terms
# Moved: MG_tratamento_para_dengue.csv -> excluded_terms
# Moved: MS_tratamento_para_dengue.csv -> excluded_terms
# Moved: MT_febre_do_mosquito.csv -> excluded_terms
# Moved: PA_febre_do_mosquito.csv -> excluded_terms
# Moved: PA_repelente_contra_dengue.csv -> excluded_terms
# Moved: PB_febre_do_mosquito.csv -> excluded_terms
# Moved: PB_repelente_contra_dengue.csv -> excluded_terms
# Moved: PE_repelente_contra_dengue.csv -> excluded_terms
# Moved: PE_tratamento_para_dengue.csv -> excluded_terms
# Moved: PI_febre_do_mosquito.csv -> excluded_terms
# Moved: PI_repelente_contra_dengue.csv -> excluded_terms
# Moved: PR_febre_do_mosquito.csv -> excluded_terms
# Moved: PR_repelente_contra_dengue.csv -> excluded_terms
# Moved: PR_tratamento_para_dengue.csv -> excluded_terms
# Moved: RJ_febre_do_mosquito.csv -> excluded_terms
# Moved: RJ_repelente_contra_dengue.csv -> excluded_terms
# Moved: RJ_tratamento_para_dengue.csv -> excluded_terms
# Moved: RN_tratamento_para_dengue.csv -> excluded_terms
# Moved: RS_febre_do_mosquito.csv -> excluded_terms
# Moved: RS_repelente_contra_dengue.csv -> excluded_terms
# Moved: RS_tratamento_para_dengue.csv -> excluded_terms
# Moved: SC_febre_do_mosquito.csv -> excluded_terms
# Moved: SC_repelente_contra_dengue.csv -> excluded_terms
# Moved: SC_tratamento_para_dengue.csv -> excluded_terms
# Moved: SE_tratamento_para_dengue.csv -> excluded_terms
# Moved: SP_febre_do_mosquito.csv -> excluded_terms
# Moved: SP_repelente_contra_dengue.csv -> excluded_terms
# Moved: SP_tratamento_para_dengue.csv -> excluded_terms
# Moved: TO_febre_do_mosquito.csv -> excluded_terms
# Moved: TO_repelente_contra_dengue.csv -> excluded_terms
# File movement completed.

# %%
import os
import shutil

# Constants
current_folder = "../serpapi_results"  # Replace with the folder where the files are stored
new_folder = "missing_logs"
excluded_terms = ["missing_data_log.txt", "missing_data_log1.txt", "missing_data_log2.txt"]

# Create a folder for excluded terms
os.makedirs(new_folder, exist_ok=True)

# Process files in the current folder
for file_name in os.listdir(current_folder):
    # Check if the file corresponds to an excluded term
    for term in excluded_terms:
        # sanitized_term = term.replace(" ", "_")
        if term in file_name:
            # Move file to the new folder
            source_path = os.path.join(current_folder, file_name)
            destination_path = os.path.join(new_folder, file_name)
            shutil.move(source_path, destination_path)
            print(f"Moved: {file_name} -> {new_folder}")

print("File movement completed.")
# Out:
# Moved: missing_data_log.txt -> missing_logs
# Moved: missing_data_log1.txt -> missing_logs
# Moved: missing_data_log2.txt -> missing_logs
# File movement completed.

# %%
import os
import pandas as pd

# Directory containing the CSV files
input_folder = "../serpapi_results"

# Dictionary to store results
filewise_counts = {}
search_term_wise_counts = {}

print("Filewise Counts:")
# Process each CSV file in the folder
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):
        file_path = os.path.join(input_folder, file_name)
        df = pd.read_csv(file_path)
        
        # Count zero and non-zero values
        count_zeros = len(df[df.Interest == 0])
        count_non_zeros = len(df[df.Interest != 0])
        
        # Extract the search term from the file name
        search_term = "_".join(file_name.split("_")[1:]).replace(".csv", "")
        
        # Accumulate search-term-wise counts
        if search_term not in search_term_wise_counts:
            search_term_wise_counts[search_term] = {"Zero Count": 0, "Non-Zero Count": 0, "File Count": 0}
        
        search_term_wise_counts[search_term]["Zero Count"] += count_zeros
        search_term_wise_counts[search_term]["Non-Zero Count"] += count_non_zeros
        search_term_wise_counts[search_term]["File Count"] += 1
        
        # Print file-wise counts
        print(f"{file_name}: zeroes: {count_zeros}, not-zero: {count_non_zeros}")

# Calculate and print averages for each search term
print("\nSearch-Term-Wise Averages:")
for search_term, counts in search_term_wise_counts.items():
    avg_zeros = counts["Zero Count"] / counts["File Count"]
    avg_non_zeros = counts["Non-Zero Count"] / counts["File Count"]
    print(f"{search_term}: Average zeroes: {avg_zeros:.2f}, Average non-zeroes: {avg_non_zeros:.2f}")
# Out:
# Filewise Counts:
# AC_dengue.csv: zeroes: 109, not-zero: 83
# AC_mosquito.csv: zeroes: 162, not-zero: 30
# AC_mosquito_da_dengue.csv: zeroes: 187, not-zero: 5
# AC_sintomas_dengue.csv: zeroes: 174, not-zero: 18
# AC_sintomas_de_dengue.csv: zeroes: 190, not-zero: 2
# AL_dengue.csv: zeroes: 84, not-zero: 108
# AL_mosquito.csv: zeroes: 88, not-zero: 104
# AL_mosquito_da_dengue.csv: zeroes: 130, not-zero: 62
# AL_sintomas_dengue.csv: zeroes: 0, not-zero: 192
# AL_sintomas_de_dengue.csv: zeroes: 0, not-zero: 192
# AM_dengue.csv: zeroes: 69, not-zero: 123
# AM_mosquito.csv: zeroes: 88, not-zero: 104
# AM_mosquito_da_dengue.csv: zeroes: 138, not-zero: 54
# AM_sintomas_dengue.csv: zeroes: 104, not-zero: 88
# AM_sintomas_de_dengue.csv: zeroes: 164, not-zero: 28
# AP_dengue.csv: zeroes: 120, not-zero: 72
# AP_mosquito_da_dengue.csv: zeroes: 185, not-zero: 7
# AP_sintomas_dengue.csv: zeroes: 183, not-zero: 9
# AP_sintomas_de_dengue.csv: zeroes: 189, not-zero: 3
# BA_dengue.csv: zeroes: 15, not-zero: 177
# BA_mosquito.csv: zeroes: 41, not-zero: 151
# BA_mosquito_da_dengue.csv: zeroes: 69, not-zero: 123
# BA_sintomas_dengue.csv: zeroes: 64, not-zero: 128
# BA_sintomas_de_dengue.csv: zeroes: 81, not-zero: 111
# CE_dengue.csv: zeroes: 25, not-zero: 167
# CE_mosquito.csv: zeroes: 61, not-zero: 131
# CE_mosquito_da_dengue.csv: zeroes: 83, not-zero: 109
# CE_sintomas_dengue.csv: zeroes: 73, not-zero: 119
# CE_sintomas_de_dengue.csv: zeroes: 100, not-zero: 92
# DF_dengue.csv: zeroes: 119, not-zero: 73
# DF_mosquito.csv: zeroes: 0, not-zero: 192
# DF_mosquito_da_dengue.csv: zeroes: 0, not-zero: 192
# DF_sintomas_de_dengue.csv: zeroes: 128, not-zero: 64
# ES_dengue.csv: zeroes: 61, not-zero: 131
# ES_mosquito.csv: zeroes: 83, not-zero: 109
# ES_mosquito_da_dengue.csv: zeroes: 94, not-zero: 98
# ES_sintomas_dengue.csv: zeroes: 81, not-zero: 111
# ES_sintomas_de_dengue.csv: zeroes: 129, not-zero: 63
# GO_dengue.csv: zeroes: 6, not-zero: 186
# GO_mosquito.csv: zeroes: 30, not-zero: 162
# GO_mosquito_da_dengue.csv: zeroes: 60, not-zero: 132
# GO_sintomas_dengue.csv: zeroes: 48, not-zero: 144
# GO_sintomas_de_dengue.csv: zeroes: 78, not-zero: 114
# MA_dengue.csv: zeroes: 69, not-zero: 123
# MA_mosquito.csv: zeroes: 92, not-zero: 100
# MA_mosquito_da_dengue.csv: zeroes: 136, not-zero: 56
# MA_sintomas_dengue.csv: zeroes: 116, not-zero: 76
# MA_sintomas_de_dengue.csv: zeroes: 172, not-zero: 20
# MG_dengue.csv: zeroes: 4, not-zero: 188
# MG_mosquito.csv: zeroes: 26, not-zero: 166
# MG_mosquito_da_dengue.csv: zeroes: 53, not-zero: 139
# MG_sintomas_dengue.csv: zeroes: 43, not-zero: 149
# MG_sintomas_de_dengue.csv: zeroes: 74, not-zero: 118
# MS_dengue.csv: zeroes: 45, not-zero: 147
# MS_mosquito.csv: zeroes: 80, not-zero: 112
# MS_mosquito_da_dengue.csv: zeroes: 117, not-zero: 75
# MS_sintomas_dengue.csv: zeroes: 89, not-zero: 103
# MS_sintomas_de_dengue.csv: zeroes: 148, not-zero: 44
# MT_dengue.csv: zeroes: 37, not-zero: 155
# MT_mosquito.csv: zeroes: 77, not-zero: 115
# MT_mosquito_da_dengue.csv: zeroes: 113, not-zero: 79
# MT_sintomas_dengue.csv: zeroes: 84, not-zero: 108
# MT_sintomas_de_dengue.csv: zeroes: 150, not-zero: 42
# PA_dengue.csv: zeroes: 54, not-zero: 138
# PA_mosquito.csv: zeroes: 84, not-zero: 108
# PA_mosquito_da_dengue.csv: zeroes: 126, not-zero: 66
# PA_sintomas_dengue.csv: zeroes: 96, not-zero: 96
# PA_sintomas_de_dengue.csv: zeroes: 150, not-zero: 42
# PB_dengue.csv: zeroes: 77, not-zero: 115
# PB_mosquito.csv: zeroes: 0, not-zero: 192
# PB_mosquito_da_dengue.csv: zeroes: 110, not-zero: 82
# PB_sintomas_dengue.csv: zeroes: 100, not-zero: 92
# PB_sintomas_de_dengue.csv: zeroes: 148, not-zero: 44
# PE_dengue.csv: zeroes: 27, not-zero: 165
# PE_mosquito.csv: zeroes: 68, not-zero: 124
# PE_mosquito_da_dengue.csv: zeroes: 87, not-zero: 105
# PE_sintomas_dengue.csv: zeroes: 78, not-zero: 114
# PE_sintomas_de_dengue.csv: zeroes: 101, not-zero: 91
# PI_dengue.csv: zeroes: 70, not-zero: 122
# PI_mosquito_da_dengue.csv: zeroes: 0, not-zero: 192
# PI_sintomas_dengue.csv: zeroes: 143, not-zero: 49
# PI_sintomas_de_dengue.csv: zeroes: 182, not-zero: 10
# PR_dengue.csv: zeroes: 10, not-zero: 182
# PR_mosquito.csv: zeroes: 35, not-zero: 157
# PR_mosquito_da_dengue.csv: zeroes: 69, not-zero: 123
# PR_sintomas_dengue.csv: zeroes: 56, not-zero: 136
# PR_sintomas_de_dengue.csv: zeroes: 81, not-zero: 111
# RJ_dengue.csv: zeroes: 2, not-zero: 190
# RJ_mosquito.csv: zeroes: 13, not-zero: 179
# RJ_mosquito_da_dengue.csv: zeroes: 54, not-zero: 138
# RJ_sintomas_dengue.csv: zeroes: 37, not-zero: 155
# RJ_sintomas_de_dengue.csv: zeroes: 77, not-zero: 115
# RN_dengue.csv: zeroes: 39, not-zero: 153
# RN_mosquito.csv: zeroes: 80, not-zero: 112
# RN_mosquito_da_dengue.csv: zeroes: 116, not-zero: 76
# RN_sintomas_dengue.csv: zeroes: 102, not-zero: 90
# RN_sintomas_de_dengue.csv: zeroes: 159, not-zero: 33
# RO_dengue.csv: zeroes: 57, not-zero: 135
# RO_mosquito.csv: zeroes: 100, not-zero: 92
# RO_sintomas_dengue.csv: zeroes: 136, not-zero: 56
# RO_sintomas_de_dengue.csv: zeroes: 183, not-zero: 9
# RR_dengue.csv: zeroes: 0, not-zero: 192
# RR_mosquito.csv: zeroes: 173, not-zero: 19
# RR_sintomas_dengue.csv: zeroes: 188, not-zero: 4
# RS_dengue.csv: zeroes: 18, not-zero: 174
# RS_mosquito.csv: zeroes: 38, not-zero: 154
# RS_mosquito_da_dengue.csv: zeroes: 66, not-zero: 126
# RS_sintomas_dengue.csv: zeroes: 67, not-zero: 125
# RS_sintomas_de_dengue.csv: zeroes: 94, not-zero: 98
# SC_dengue.csv: zeroes: 29, not-zero: 163
# SC_mosquito.csv: zeroes: 43, not-zero: 149
# SC_mosquito_da_dengue.csv: zeroes: 83, not-zero: 109
# SC_sintomas_dengue.csv: zeroes: 83, not-zero: 109
# SC_sintomas_de_dengue.csv: zeroes: 118, not-zero: 74
# SE_dengue.csv: zeroes: 0, not-zero: 192
# SE_mosquito.csv: zeroes: 103, not-zero: 89
# SE_mosquito_da_dengue.csv: zeroes: 151, not-zero: 41
# SE_sintomas_dengue.csv: zeroes: 133, not-zero: 59
# SE_sintomas_de_dengue.csv: zeroes: 176, not-zero: 16
# SP_dengue.csv: zeroes: 0, not-zero: 192
# SP_mosquito.csv: zeroes: 4, not-zero: 188
# SP_mosquito_da_dengue.csv: zeroes: 32, not-zero: 160
# SP_sintomas_dengue.csv: zeroes: 29, not-zero: 163
# SP_sintomas_de_dengue.csv: zeroes: 54, not-zero: 138
# TO_dengue.csv: zeroes: 0, not-zero: 192
# TO_mosquito.csv: zeroes: 121, not-zero: 71
# TO_mosquito_da_dengue.csv: zeroes: 159, not-zero: 33
# TO_sintomas_dengue.csv: zeroes: 0, not-zero: 192
# TO_sintomas_de_dengue.csv: zeroes: 183, not-zero: 9
#
# Search-Term-Wise Averages:
# dengue: Average zeroes: 42.44, Average non-zeroes: 149.56
# mosquito: Average zeroes: 67.60, Average non-zeroes: 124.40
# mosquito_da_dengue: Average zeroes: 96.72, Average non-zeroes: 95.28
# sintomas_dengue: Average zeroes: 88.73, Average non-zeroes: 103.27
# sintomas_de_dengue: Average zeroes: 127.27, Average non-zeroes: 64.73

# %%
df=pd.read_csv('../code/reduced.csv')
df.dep_id.unique()
# Out:
# array([11, 12, 13, 14, 15, 16, 17, 21, 22, 23, 24, 25, 26, 27, 28, 29, 31,
#        32, 33, 35, 41, 42, 43, 50, 51, 52, 53], dtype=int64)

# %%
import os
import pandas as pd

# Map for converting Portuguese month abbreviations to numbers
month_map = {
    "jan.": "01", "fev.": "02", "mar.": "03", "abr.": "04", "mai.": "05", "jun.": "06",
    "jul.": "07", "ago.": "08", "set.": "09", "out.": "10", "nov.": "11", "dez.": "12"
}

# Folder containing the CSV files
input_folder = "../serpapi_results"
output_folder = "../serpapi_results_converted"
os.makedirs(output_folder, exist_ok=True)

# Process each CSV file
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):
        file_path = os.path.join(input_folder, file_name)
        df = pd.read_csv(file_path)
        
        # Convert the Date column
        def convert_date(date_str):
            month_abbr, year = date_str.split(" ")
            month = month_map[month_abbr]
            return f"{year}-{month}"
        
        df["Date"] = df["Date"].apply(convert_date)
        
        # Save the updated DataFrame to a new file
        output_path = os.path.join(output_folder, file_name)
        df.to_csv(output_path, index=False, encoding="utf-8")
        print(f"Processed and saved: {output_path}")
# Out:
# Processed and saved: ../serpapi_results_converted\AC_dengue.csv
# Processed and saved: ../serpapi_results_converted\AC_mosquito.csv
# Processed and saved: ../serpapi_results_converted\AC_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\AC_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\AC_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\AL_dengue.csv
# Processed and saved: ../serpapi_results_converted\AL_mosquito.csv
# Processed and saved: ../serpapi_results_converted\AL_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\AL_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\AL_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\AM_dengue.csv
# Processed and saved: ../serpapi_results_converted\AM_mosquito.csv
# Processed and saved: ../serpapi_results_converted\AM_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\AM_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\AM_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\AP_dengue.csv
# Processed and saved: ../serpapi_results_converted\AP_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\AP_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\AP_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\BA_dengue.csv
# Processed and saved: ../serpapi_results_converted\BA_mosquito.csv
# Processed and saved: ../serpapi_results_converted\BA_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\BA_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\BA_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\CE_dengue.csv
# Processed and saved: ../serpapi_results_converted\CE_mosquito.csv
# Processed and saved: ../serpapi_results_converted\CE_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\CE_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\CE_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\DF_dengue.csv
# Processed and saved: ../serpapi_results_converted\DF_mosquito.csv
# Processed and saved: ../serpapi_results_converted\DF_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\DF_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\ES_dengue.csv
# Processed and saved: ../serpapi_results_converted\ES_mosquito.csv
# Processed and saved: ../serpapi_results_converted\ES_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\ES_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\ES_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\GO_dengue.csv
# Processed and saved: ../serpapi_results_converted\GO_mosquito.csv
# Processed and saved: ../serpapi_results_converted\GO_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\GO_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\GO_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\MA_dengue.csv
# Processed and saved: ../serpapi_results_converted\MA_mosquito.csv
# Processed and saved: ../serpapi_results_converted\MA_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\MA_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\MA_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\MG_dengue.csv
# Processed and saved: ../serpapi_results_converted\MG_mosquito.csv
# Processed and saved: ../serpapi_results_converted\MG_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\MG_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\MG_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\MS_dengue.csv
# Processed and saved: ../serpapi_results_converted\MS_mosquito.csv
# Processed and saved: ../serpapi_results_converted\MS_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\MS_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\MS_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\MT_dengue.csv
# Processed and saved: ../serpapi_results_converted\MT_mosquito.csv
# Processed and saved: ../serpapi_results_converted\MT_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\MT_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\MT_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\PA_dengue.csv
# Processed and saved: ../serpapi_results_converted\PA_mosquito.csv
# Processed and saved: ../serpapi_results_converted\PA_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\PA_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\PA_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\PB_dengue.csv
# Processed and saved: ../serpapi_results_converted\PB_mosquito.csv
# Processed and saved: ../serpapi_results_converted\PB_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\PB_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\PB_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\PE_dengue.csv
# Processed and saved: ../serpapi_results_converted\PE_mosquito.csv
# Processed and saved: ../serpapi_results_converted\PE_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\PE_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\PE_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\PI_dengue.csv
# Processed and saved: ../serpapi_results_converted\PI_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\PI_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\PI_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\PR_dengue.csv
# Processed and saved: ../serpapi_results_converted\PR_mosquito.csv
# Processed and saved: ../serpapi_results_converted\PR_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\PR_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\PR_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\RJ_dengue.csv
# Processed and saved: ../serpapi_results_converted\RJ_mosquito.csv
# Processed and saved: ../serpapi_results_converted\RJ_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\RJ_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\RJ_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\RN_dengue.csv
# Processed and saved: ../serpapi_results_converted\RN_mosquito.csv
# Processed and saved: ../serpapi_results_converted\RN_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\RN_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\RN_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\RO_dengue.csv
# Processed and saved: ../serpapi_results_converted\RO_mosquito.csv
# Processed and saved: ../serpapi_results_converted\RO_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\RO_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\RR_dengue.csv
# Processed and saved: ../serpapi_results_converted\RR_mosquito.csv
# Processed and saved: ../serpapi_results_converted\RR_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\RS_dengue.csv
# Processed and saved: ../serpapi_results_converted\RS_mosquito.csv
# Processed and saved: ../serpapi_results_converted\RS_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\RS_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\RS_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\SC_dengue.csv
# Processed and saved: ../serpapi_results_converted\SC_mosquito.csv
# Processed and saved: ../serpapi_results_converted\SC_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\SC_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\SC_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\SE_dengue.csv
# Processed and saved: ../serpapi_results_converted\SE_mosquito.csv
# Processed and saved: ../serpapi_results_converted\SE_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\SE_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\SE_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\SP_dengue.csv
# Processed and saved: ../serpapi_results_converted\SP_mosquito.csv
# Processed and saved: ../serpapi_results_converted\SP_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\SP_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\SP_sintomas_de_dengue.csv
# Processed and saved: ../serpapi_results_converted\TO_dengue.csv
# Processed and saved: ../serpapi_results_converted\TO_mosquito.csv
# Processed and saved: ../serpapi_results_converted\TO_mosquito_da_dengue.csv
# Processed and saved: ../serpapi_results_converted\TO_sintomas_dengue.csv
# Processed and saved: ../serpapi_results_converted\TO_sintomas_de_dengue.csv

# %%
import os

# Output folder containing converted files
output_folder = "../serpapi_results_converted"

# Search terms and department names
search_terms = ["sintomas dengue", "dengue", "mosquito"]
DEP_NAMES = {
    0: 'RO', 1: 'AC', 2: 'AM', 3: 'RR', 4: 'PA', 5: 'AP', 6: 'TO',
    7: 'MA', 8: 'PI', 9: 'CE', 10: 'RN', 11: 'PB', 12: 'PE',
    13: 'AL', 14: 'SE', 15: 'BA', 16: 'MG', 17: 'ES', 18: 'RJ',
    19: 'SP', 20: 'PR', 21: 'SC', 22: 'RS', 23: 'MS', 24: 'MT',
    25: 'GO', 26: 'DF'
}

# Generate all expected file combinations
expected_files = [f"{dep}_{term.replace(' ', '_')}.csv" for dep in DEP_NAMES.values() for term in search_terms]

# List files in the output folder
existing_files = os.listdir(output_folder)

# Check for missing files
missing_files = [file for file in expected_files if file not in existing_files]

# Print missing combinations
print("Missing File Combinations:")
for file in missing_files:
    print(file)
# Out:
# Missing File Combinations:

# %%
import os
import csv
import json
from serpapi import GoogleSearch

# Constants
search_terms = [
    "mosquito"
]
DEP_NAMES = {
    9: 'CE'
}
timeframe = "2004-01-01 2019-12-01"  # Expanded timeframe
api_key = "7e8d78c24551d970db3f53487e45a82c232180250e17fab6a5eede7c3ee0c70c"

# Create a folder to save results
output_folder = "serpapi_results_new"
os.makedirs(output_folder, exist_ok=True)

# Initialize a list to track missing data combinations
missing_data_combinations = []

# Process each state and each search term
for state_code in DEP_NAMES.values():
    for search_term in search_terms:
        # Parameters for the SerpAPI request
        params = {
            "engine": "google_trends",
            "q": search_term,
            "geo": f"BR-{state_code}",
            "hl": "pt",  # Portuguese for Brazil
            "date": timeframe,
            "api_key": api_key
        }

        # Output file path
        output_file = os.path.join(output_folder, f"{state_code}_{search_term.replace(' ', '_')}.csv")

        # Fetch data from SerpAPI
        try:
            print(f"Fetching data for State: {state_code}, Search Term: {search_term}")
            search = GoogleSearch(params)
            result = search.get_dict()  # Convert response to a dictionary

            # Debugging: Print the raw response to understand its structure
            print("Response received:")
            # print(json.dumps(result, indent=4, ensure_ascii=False))

            # Extract interest over time data
            interest_data = result.get("interest_over_time", {}).get("timeline_data", [])
            
            if interest_data:
                # Save results to a CSV file
                with open(output_file, mode="w", newline="", encoding="utf-8") as file:
                    writer = csv.writer(file)
                    writer.writerow(["Date", "Interest"])
                    
                    for entry in interest_data:
                        date = entry.get("date")
                        values = entry.get("values", [])
                        partial_data = entry.get("partial_data", False)
                        
                        # Only process non-partial weeks with valid values
                        if not partial_data and values:
                            interest_value = values[0].get("value", 0)
                            writer.writerow([date, interest_value])
                
                print(f"Data saved to {output_file}")
            else:
                print(f"No data found for State: {state_code}, Search Term: {search_term}")
                missing_data_combinations.append((state_code, search_term))
        except Exception as e:
            print(f"An error occurred for State: {state_code}, Search Term: {search_term}: {e}")
            missing_data_combinations.append((state_code, search_term))

# Log missing data combinations
if missing_data_combinations:
    missing_file = os.path.join(output_folder, "missing_data_log.txt")
    with open(missing_file, "w", encoding="utf-8") as log_file:
        log_file.write("No data found for the following State-Search Term combinations:\n")
        for state, term in missing_data_combinations:
            log_file.write(f"State: {state}, Search Term: {term}\n")
    print(f"Missing data logged to {missing_file}")
else:
    print("All data successfully fetched and saved.")
# Out:
# Fetching data for State: CE, Search Term: mosquito
# Response received:
# Data saved to serpapi_results_new\CE_mosquito.csv
# All data successfully fetched and saved.

# %%
import os
import pandas as pd

# Input folder containing the CSV files
input_folder = "../serpapi_results_converted"
output_folder = "../serpapi_results_cleaned"

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Process each file in the input folder
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):
        file_path = os.path.join(input_folder, file_name)
        
        try:
            # Read the file
            df = pd.read_csv(file_path)

            # Check for "<1" and replace it with 0.5
            df["Interest"] = df["Interest"].replace("<1", 0.5)

            # Convert Interest column to float
            df["Interest"] = df["Interest"].astype(float)

            # Save the cleaned file to the output folder
            output_path = os.path.join(output_folder, file_name)
            df.to_csv(output_path, index=False)
            print(f"Processed and saved: {file_name}")

        except Exception as e:
            print(f"Error processing {file_name}: {e}")
# Out:
# Processed and saved: AC_dengue.csv
# Processed and saved: AC_mosquito.csv
# Processed and saved: AC_mosquito_da_dengue.csv
# Processed and saved: AC_sintomas_dengue.csv
# Processed and saved: AC_sintomas_de_dengue.csv
# Processed and saved: AL_dengue.csv
# Processed and saved: AL_mosquito.csv
# Processed and saved: AL_mosquito_da_dengue.csv
# Processed and saved: AL_sintomas_dengue.csv
# Processed and saved: AL_sintomas_de_dengue.csv
# Processed and saved: AM_dengue.csv
# Processed and saved: AM_mosquito.csv
# Processed and saved: AM_mosquito_da_dengue.csv
# Processed and saved: AM_sintomas_dengue.csv
# Processed and saved: AM_sintomas_de_dengue.csv
# Processed and saved: AP_dengue.csv
# Processed and saved: AP_mosquito.csv
# Processed and saved: AP_mosquito_da_dengue.csv
# Processed and saved: AP_sintomas_dengue.csv
# Processed and saved: AP_sintomas_de_dengue.csv
# Processed and saved: BA_dengue.csv
# Processed and saved: BA_mosquito.csv
# Processed and saved: BA_mosquito_da_dengue.csv
# Processed and saved: BA_sintomas_dengue.csv
# Processed and saved: BA_sintomas_de_dengue.csv
# Processed and saved: CE_dengue.csv
# Processed and saved: CE_mosquito.csv
# Processed and saved: CE_mosquito_da_dengue.csv
# Processed and saved: CE_sintomas_dengue.csv
# Processed and saved: CE_sintomas_de_dengue.csv
# Processed and saved: DF_dengue.csv
# Processed and saved: DF_mosquito.csv
# Processed and saved: DF_mosquito_da_dengue.csv
# Processed and saved: DF_sintomas_dengue.csv
# Processed and saved: DF_sintomas_de_dengue.csv
# Processed and saved: ES_dengue.csv
# Processed and saved: ES_mosquito.csv
# Processed and saved: ES_mosquito_da_dengue.csv
# Processed and saved: ES_sintomas_dengue.csv
# Processed and saved: ES_sintomas_de_dengue.csv
# Processed and saved: GO_dengue.csv
# Processed and saved: GO_mosquito.csv
# Processed and saved: GO_mosquito_da_dengue.csv
# Processed and saved: GO_sintomas_dengue.csv
# Processed and saved: GO_sintomas_de_dengue.csv
# Processed and saved: MA_dengue.csv
# Processed and saved: MA_mosquito.csv
# Processed and saved: MA_mosquito_da_dengue.csv
# Processed and saved: MA_sintomas_dengue.csv
# Processed and saved: MA_sintomas_de_dengue.csv
# Processed and saved: MG_dengue.csv
# Processed and saved: MG_mosquito.csv
# Processed and saved: MG_mosquito_da_dengue.csv
# Processed and saved: MG_sintomas_dengue.csv
# Processed and saved: MG_sintomas_de_dengue.csv
# Processed and saved: MS_dengue.csv
# Processed and saved: MS_mosquito.csv
# Processed and saved: MS_mosquito_da_dengue.csv
# Processed and saved: MS_sintomas_dengue.csv
# Processed and saved: MS_sintomas_de_dengue.csv
# Processed and saved: MT_dengue.csv
# Processed and saved: MT_mosquito.csv
# Processed and saved: MT_mosquito_da_dengue.csv
# Processed and saved: MT_sintomas_dengue.csv
# Processed and saved: MT_sintomas_de_dengue.csv
# Processed and saved: PA_dengue.csv
# Processed and saved: PA_mosquito.csv
# Processed and saved: PA_mosquito_da_dengue.csv
# Processed and saved: PA_sintomas_dengue.csv
# Processed and saved: PA_sintomas_de_dengue.csv
# Processed and saved: PB_dengue.csv
# Processed and saved: PB_mosquito.csv
# Processed and saved: PB_mosquito_da_dengue.csv
# Processed and saved: PB_sintomas_dengue.csv
# Processed and saved: PB_sintomas_de_dengue.csv
# Processed and saved: PE_dengue.csv
# Processed and saved: PE_mosquito.csv
# Processed and saved: PE_mosquito_da_dengue.csv
# Processed and saved: PE_sintomas_dengue.csv
# Processed and saved: PE_sintomas_de_dengue.csv
# Processed and saved: PI_dengue.csv
# Processed and saved: PI_mosquito.csv
# Processed and saved: PI_mosquito_da_dengue.csv
# Processed and saved: PI_sintomas_dengue.csv
# Processed and saved: PI_sintomas_de_dengue.csv
# Processed and saved: PR_dengue.csv
# Processed and saved: PR_mosquito.csv
# Processed and saved: PR_mosquito_da_dengue.csv
# Processed and saved: PR_sintomas_dengue.csv
# Processed and saved: PR_sintomas_de_dengue.csv
# Processed and saved: RJ_dengue.csv
# Processed and saved: RJ_mosquito.csv
# Processed and saved: RJ_mosquito_da_dengue.csv
# Processed and saved: RJ_sintomas_dengue.csv
# Processed and saved: RJ_sintomas_de_dengue.csv
# Processed and saved: RN_dengue.csv
# Processed and saved: RN_mosquito.csv
# Processed and saved: RN_mosquito_da_dengue.csv
# Processed and saved: RN_sintomas_dengue.csv
# Processed and saved: RN_sintomas_de_dengue.csv
# Processed and saved: RO_dengue.csv
# Processed and saved: RO_mosquito.csv
# Processed and saved: RO_sintomas_dengue.csv
# Processed and saved: RO_sintomas_de_dengue.csv
# Processed and saved: RR_dengue.csv
# Processed and saved: RR_mosquito.csv
# Processed and saved: RR_sintomas_dengue.csv
# Processed and saved: RS_dengue.csv
# Processed and saved: RS_mosquito.csv
# Processed and saved: RS_mosquito_da_dengue.csv
# Processed and saved: RS_sintomas_dengue.csv
# Processed and saved: RS_sintomas_de_dengue.csv
# Processed and saved: SC_dengue.csv
# Processed and saved: SC_mosquito.csv
# Processed and saved: SC_mosquito_da_dengue.csv
# Processed and saved: SC_sintomas_dengue.csv
# Processed and saved: SC_sintomas_de_dengue.csv
# Processed and saved: SE_dengue.csv
# Processed and saved: SE_mosquito.csv
# Processed and saved: SE_mosquito_da_dengue.csv
# Processed and saved: SE_sintomas_dengue.csv
# Processed and saved: SE_sintomas_de_dengue.csv
# Processed and saved: SP_dengue.csv
# Processed and saved: SP_mosquito.csv
# Processed and saved: SP_mosquito_da_dengue.csv
# Processed and saved: SP_sintomas_dengue.csv
# Processed and saved: SP_sintomas_de_dengue.csv
# Processed and saved: TO_dengue.csv
# Processed and saved: TO_mosquito.csv
# Processed and saved: TO_mosquito_da_dengue.csv
# Processed and saved: TO_sintomas_dengue.csv
# Processed and saved: TO_sintomas_de_dengue.csv

# %%
import os
import shutil

# Input folder containing all the files
input_folder = "../serpapi_results_cleaned"
output_folder = "../serpapi_results_filtered"

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Search terms to keep
keep_terms = ["dengue", "mosquito", "sintomas dengue"]

# Search terms to filter out
exclude_terms = [
    "sintomas de dengue", "mosquito da dengue", "febre do mosquito",
    "repelente contra dengue", "tratamento para dengue"
]

# Process each file
for file_name in os.listdir(input_folder):
    # Check if the filename matches any of the terms to keep
    if any(term.replace(" ", "_") in file_name for term in keep_terms):
        # Ensure it doesn't match any of the exclude terms
        if not any(term.replace(" ", "_") in file_name for term in exclude_terms):
            source_path = os.path.join(input_folder, file_name)
            destination_path = os.path.join(output_folder, file_name)
            
            # Copy the file to the filtered folder
            shutil.copy(source_path, destination_path)
            print(f"Copied: {file_name}")

print(f"Filtered files saved to: {output_folder}")
# Out:
# Copied: AC_dengue.csv
# Copied: AC_mosquito.csv
# Copied: AC_sintomas_dengue.csv
# Copied: AL_dengue.csv
# Copied: AL_mosquito.csv
# Copied: AL_sintomas_dengue.csv
# Copied: AM_dengue.csv
# Copied: AM_mosquito.csv
# Copied: AM_sintomas_dengue.csv
# Copied: AP_dengue.csv
# Copied: AP_mosquito.csv
# Copied: AP_sintomas_dengue.csv
# Copied: BA_dengue.csv
# Copied: BA_mosquito.csv
# Copied: BA_sintomas_dengue.csv
# Copied: CE_dengue.csv
# Copied: CE_mosquito.csv
# Copied: CE_sintomas_dengue.csv
# Copied: DF_dengue.csv
# Copied: DF_mosquito.csv
# Copied: DF_sintomas_dengue.csv
# Copied: ES_dengue.csv
# Copied: ES_mosquito.csv
# Copied: ES_sintomas_dengue.csv
# Copied: GO_dengue.csv
# Copied: GO_mosquito.csv
# Copied: GO_sintomas_dengue.csv
# Copied: MA_dengue.csv
# Copied: MA_mosquito.csv
# Copied: MA_sintomas_dengue.csv
# Copied: MG_dengue.csv
# Copied: MG_mosquito.csv
# Copied: MG_sintomas_dengue.csv
# Copied: MS_dengue.csv
# Copied: MS_mosquito.csv
# Copied: MS_sintomas_dengue.csv
# Copied: MT_dengue.csv
# Copied: MT_mosquito.csv
# Copied: MT_sintomas_dengue.csv
# Copied: PA_dengue.csv
# Copied: PA_mosquito.csv
# Copied: PA_sintomas_dengue.csv
# Copied: PB_dengue.csv
# Copied: PB_mosquito.csv
# Copied: PB_sintomas_dengue.csv
# Copied: PE_dengue.csv
# Copied: PE_mosquito.csv
# Copied: PE_sintomas_dengue.csv
# Copied: PI_dengue.csv
# Copied: PI_mosquito.csv
# Copied: PI_sintomas_dengue.csv
# Copied: PR_dengue.csv
# Copied: PR_mosquito.csv
# Copied: PR_sintomas_dengue.csv
# Copied: RJ_dengue.csv
# Copied: RJ_mosquito.csv
# Copied: RJ_sintomas_dengue.csv
# Copied: RN_dengue.csv
# Copied: RN_mosquito.csv
# Copied: RN_sintomas_dengue.csv
# Copied: RO_dengue.csv
# Copied: RO_mosquito.csv
# Copied: RO_sintomas_dengue.csv
# Copied: RR_dengue.csv
# Copied: RR_mosquito.csv
# Copied: RR_sintomas_dengue.csv
# Copied: RS_dengue.csv
# Copied: RS_mosquito.csv
# Copied: RS_sintomas_dengue.csv
# Copied: SC_dengue.csv
# Copied: SC_mosquito.csv
# Copied: SC_sintomas_dengue.csv
# Copied: SE_dengue.csv
# Copied: SE_mosquito.csv
# Copied: SE_sintomas_dengue.csv
# Copied: SP_dengue.csv
# Copied: SP_mosquito.csv
# Copied: SP_sintomas_dengue.csv
# Copied: TO_dengue.csv
# Copied: TO_mosquito.csv
# Copied: TO_sintomas_dengue.csv
# Filtered files saved to: ../serpapi_results_filtered

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Input folder containing the CSV files
input_folder = "../serpapi_results_filtered"

# Parameters
decomposition_model = "additive"  # Choose between 'additive' or 'multiplicative'
period = 12  # Monthly data, so period = 12

# Group data for visualization
state_data = {}
search_term_data = {}

# Process each file
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):
        # Extract state and search term from file name
        file_path = os.path.join(input_folder, file_name)
        state = file_name.split("_")[0]  # Assuming state is the first part
        search_term = file_name.split("_", 1)[1].replace(".csv", "")  # Rest is search term

        # Read the file
        try:
            data = pd.read_csv(file_path, parse_dates=["Date"], index_col="Date")
            data["Interest"] = pd.to_numeric(data["Interest"], errors="coerce")

            # Perform decomposition
            decomposition = seasonal_decompose(data["Interest"].dropna(), model=decomposition_model, period=period)

            # Store components for visualization
            state_data.setdefault(state, []).append(decomposition)
            search_term_data.setdefault(search_term, []).append(decomposition)

            # Visualize decomposition (state-wise)
            plt.figure(figsize=(14, 10))
            plt.suptitle(f"{state} - {search_term} Decomposition", fontsize=16)

            plt.subplot(411)
            plt.plot(decomposition.observed, label="Observed")
            plt.legend(loc="best")
            plt.subplot(412)
            plt.plot(decomposition.trend, label="Trend")
            plt.legend(loc="best")
            plt.subplot(413)
            plt.plot(decomposition.seasonal, label="Seasonality")
            plt.legend(loc="best")
            plt.subplot(414)
            plt.plot(decomposition.resid, label="Residual")
            plt.legend(loc="best")

            plt.tight_layout(rect=[0, 0, 1, 0.96])
            plt.show()

        except Exception as e:
            print(f"Error processing file {file_name}: {e}")

# Combined plots for states (grouped across search terms)
for state, decompositions in state_data.items():
    plt.figure(figsize=(14, 10))
    plt.suptitle(f"{state} - Combined Search Terms Decomposition", fontsize=16)
    for i, decomposition in enumerate(decompositions):
        plt.subplot(len(decompositions), 1, i + 1)
        plt.plot(decomposition.trend, label=f"Trend ({state})")
        plt.plot(decomposition.seasonal, label="Seasonal", linestyle="--")
        plt.legend(loc="best")
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# Combined plots for search terms (grouped across states)
for search_term, decompositions in search_term_data.items():
    plt.figure(figsize=(14, 10))
    plt.suptitle(f"{search_term} - Combined States Decomposition", fontsize=16)
    for i, decomposition in enumerate(decompositions):
        plt.subplot(len(decompositions), 1, i + 1)
        plt.plot(decomposition.trend, label=f"Trend ({search_term})")
        plt.plot(decomposition.seasonal, label="Seasonal", linestyle="--")
        plt.legend(loc="best")
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %%
import pandas as pd
import os

# Load the main dataset
main_data_path = '../code/reduced_2004_2019.csv'
main_data = pd.read_csv(main_data_path)

# Correct scaled Month column and generate Date column
main_data['Month'] = (main_data.groupby(['Year']).cumcount() % 12 + 1)  # Generate month if not present
main_data['Date'] = pd.to_datetime(main_data['Year'].astype(str) + '-' + main_data['Month'].astype(str).str.zfill(2))

# Mapping of Brazilian states
brazil_states = {
    11: {"name": "Rondônia", "code": "RO"}, 12: {"name": "Acre", "code": "AC"}, 13: {"name": "Amazonas", "code": "AM"},
    14: {"name": "Roraima", "code": "RR"}, 15: {"name": "Pará", "code": "PA"}, 16: {"name": "Amapá", "code": "AP"},
    17: {"name": "Tocantins", "code": "TO"}, 21: {"name": "Maranhão", "code": "MA"}, 22: {"name": "Piauí", "code": "PI"},
    23: {"name": "Ceará", "code": "CE"}, 24: {"name": "Rio Grande do Norte", "code": "RN"},
    25: {"name": "Paraíba", "code": "PB"}, 26: {"name": "Pernambuco", "code": "PE"}, 27: {"name": "Alagoas", "code": "AL"},
    28: {"name": "Sergipe", "code": "SE"}, 29: {"name": "Bahia", "code": "BA"}, 31: {"name": "Minas Gerais", "code": "MG"},
    32: {"name": "Espírito Santo", "code": "ES"}, 33: {"name": "Rio de Janeiro", "code": "RJ"},
    35: {"name": "São Paulo", "code": "SP"}, 41: {"name": "Paraná", "code": "PR"},
    42: {"name": "Santa Catarina", "code": "SC"}, 43: {"name": "Rio Grande do Sul", "code": "RS"},
    50: {"name": "Mato Grosso do Sul", "code": "MS"}, 51: {"name": "Mato Grosso", "code": "MT"},
    52: {"name": "Goiás", "code": "GO"}, 53: {"name": "Distrito Federal", "code": "DF"}
}

# Reverse map for quick lookup
state_code_to_dep_id = {v['code']: k for k, v in brazil_states.items()}

# Example trends files (introducing more files)
trends_files = [
    '../serpapi_results_filtered/AC_mosquito.csv',
    '../serpapi_results_filtered/AC_sintomas_dengue.csv',
    '../serpapi_results_filtered/AC_dengue.csv',
    '../serpapi_results_filtered/AM_mosquito.csv',
    '../serpapi_results_filtered/AM_sintomas_dengue.csv',
    '../serpapi_results_filtered/AM_dengue.csv'
]


# Initialize trend columns for all search terms
search_terms = ['mosquito', 'sintomas_dengue', 'dengue']
for term in search_terms:
    main_data[f'{term}_interest'] = pd.NA

# Iterate through trends files
for file_name in trends_files:
    # Extract state code and search term from file name
    base_name = os.path.basename(file_name)  # Extracts 'AC_mosquito.csv'
    state_code, search_term = base_name.split('_')[0], '_'.join(base_name.split('_')[1:]).replace('.csv', '')
    dep_id = state_code_to_dep_id.get(state_code)
    
    if not dep_id:
        print(f"Skipping file {file_name} (state code {state_code} not found)")
        continue

    # Load the trends file
    trends_data = pd.read_csv(file_name)

    # Parse date in trends data
    trends_data['Date'] = pd.to_datetime(trends_data['Date'], format='%Y-%m')

    # Rename the Interest column to include the search term
    trends_data = trends_data.rename(columns={'Interest': f'{search_term}_interest'})

    # Filter main_data for the current district
    district_data = main_data[main_data['dep_id'] == dep_id]

    # Merge trends data into the filtered district data
    district_data = pd.merge(
        district_data, trends_data[['Date', f'{search_term}_interest']],
        on='Date', how='left'
    )

    # Update the original main_data only for the current district and search term
    main_data.loc[main_data['dep_id'] == dep_id, f'{search_term}_interest'] = district_data[f'{search_term}_interest']

# Save the final merged dataset
main_data.to_csv('merged_dataset.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\minornew\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mosquito_interest'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 76
#      70     district_data = pd.merge(
#      71         district_data, trends_data[['Date', f'{search_term}_interest']],
#      72         on='Date', how='left'
#      73     )
#      75     # Update the original main_data only for the current district and search term
# ---> 76     main_data.loc[main_data['dep_id'] == dep_id, f'{search_term}_interest'] = district_data[f'{search_term}_interest']
#      78 # Save the final merged dataset
#      79 main_data.to_csv('merged_dataset.csv', index=False)
#
# File ~\anaconda3\envs\minornew\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\minornew\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'mosquito_interest'
