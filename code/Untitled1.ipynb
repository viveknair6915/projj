# %%
Training the model...
Epoch 1/50
456/456 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6380 - mae: 0.5768
Epoch 1: val_loss improved from inf to 0.00741, saving model to E:\minor\proj\code\saved_models\Brazil\best_tcn_model.keras
456/456 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - loss: 0.6372 - mae: 0.5763 - val_loss: 0.0074 - val_mae: 0.0629
Epoch 2/50
456/456 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0459 - mae: 0.1663
Epoch 2: val_loss improved from 0.00741 to 0.00684, saving model to E:\minor\proj\code\saved_models\Brazil\best_tcn_model.keras
456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0458 - mae: 0.1662 - val_loss: 0.0068 - val_mae: 0.0703
Epoch 3/50
456/456 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0190 - mae: 0.1035
Epoch 3: val_loss improved from 0.00684 to 0.00437, saving model to E:\minor\proj\code\saved_models\Brazil\best_tcn_model.keras
456/456 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0190 - mae: 0.1034 - val_loss: 0.0044 - val_mae: 0.0384
Epoch 4/50
455/456 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0119 - mae: 0.0769
Epoch 4: val_loss did not improve from 0.00437
456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0119 - mae: 0.0768 - val_loss: 0.0130 - val_mae: 0.1070
Epoch 5/50
456/456 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0091 - mae: 0.0633
Epoch 5: val_loss did not improve from 0.00437
456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0091 - mae: 0.0633 - val_loss: 0.0128 - val_mae: 0.0924
Epoch 6/50
453/456 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0078 - mae: 0.0548
Epoch 6: val_loss did not improve from 0.00437
456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.0078 - mae: 0.0548 - val_loss: 0.0114 - val_mae: 0.0842
Epoch 7/50
456/456 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0075 - mae: 0.0532
Epoch 7: val_loss did not improve from 0.00437
456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.0075 - mae: 0.0532 - val_loss: 0.0090 - val_mae: 0.0683
Epoch 8/50
450/456 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0069 - mae: 0.0495
Epoch 8: val_loss did not improve from 0.00437
456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0069 - mae: 0.0495 - val_loss: 0.0067 - val_mae: 0.0481
Epoch 8: early stopping
Restoring model weights from the end of the best epoch: 3.
Model saved to: E:\minor\proj\code\saved_models\Brazil\TCN_final_model_15-11-2024-23-29-11.keras

# %%
Trial 20 Complete [00h 01m 00s]
val_loss: 0.04666542448103428

Best val_loss So Far: 0.001267109822947532
Total elapsed time: 00h 28m 24s
Results summary
Results in hyperparam_tuning\tcn_dengue_forecast
Showing 10 best trials
Objective(name="val_loss", direction="min")

Trial 06 summary
Hyperparameters:
num_layers: 2
filters_0: 128
kernel_size_0: 2
batch_norm_0: False
dropout_0: 0.4
filters_1: 32
kernel_size_1: 3
batch_norm_1: True
dropout_1: 0.30000000000000004
learning_rate: 0.005115498689266476
filters_2: 32
kernel_size_2: 5
batch_norm_2: True
dropout_2: 0.30000000000000004
filters_3: 32
kernel_size_3: 5
batch_norm_3: True
dropout_3: 0.4
filters_4: 64
kernel_size_4: 5
batch_norm_4: False
dropout_4: 0.1
Score: 0.001267109822947532

Trial 07 summary
Hyperparameters:
num_layers: 4
filters_0: 32
kernel_size_0: 5
batch_norm_0: True
dropout_0: 0.5
filters_1: 128
kernel_size_1: 3
batch_norm_1: False
dropout_1: 0.30000000000000004
learning_rate: 0.0006600528210015756
filters_2: 128
kernel_size_2: 3
batch_norm_2: True
dropout_2: 0.1
filters_3: 128
kernel_size_3: 3
batch_norm_3: True
dropout_3: 0.1
filters_4: 128
kernel_size_4: 5
batch_norm_4: True
dropout_4: 0.4
Score: 0.0025720236590132117

Trial 04 summary
Hyperparameters:
num_layers: 3
filters_0: 64
kernel_size_0: 5
batch_norm_0: True
dropout_0: 0.1
filters_1: 64
kernel_size_1: 5
batch_norm_1: False
dropout_1: 0.1
learning_rate: 0.0001231004831757312
filters_2: 64
kernel_size_2: 5
batch_norm_2: False
dropout_2: 0.30000000000000004
filters_3: 128
kernel_size_3: 5
batch_norm_3: True
dropout_3: 0.1
filters_4: 64
kernel_size_4: 5
batch_norm_4: True
dropout_4: 0.2
Score: 0.002848276519216597

Trial 16 summary
Hyperparameters:
num_layers: 2
filters_0: 32
kernel_size_0: 3
batch_norm_0: False
dropout_0: 0.5
filters_1: 64
kernel_size_1: 5
batch_norm_1: True
dropout_1: 0.4
learning_rate: 0.0017080390761761853
filters_2: 128
kernel_size_2: 5
batch_norm_2: False
dropout_2: 0.30000000000000004
filters_3: 128
kernel_size_3: 5
batch_norm_3: False
dropout_3: 0.1
filters_4: 32
kernel_size_4: 2
batch_norm_4: True
dropout_4: 0.30000000000000004
Score: 0.004585759830661118

Trial 13 summary
Hyperparameters:
num_layers: 4
filters_0: 128
kernel_size_0: 3
batch_norm_0: True
dropout_0: 0.1
filters_1: 64
kernel_size_1: 2
batch_norm_1: False
dropout_1: 0.1
learning_rate: 0.005426206015066994
filters_2: 64
kernel_size_2: 5
batch_norm_2: True
dropout_2: 0.1
filters_3: 64
kernel_size_3: 5
batch_norm_3: True
dropout_3: 0.30000000000000004
filters_4: 32
kernel_size_4: 2
batch_norm_4: True
dropout_4: 0.2
Score: 0.006576405838131905

Trial 10 summary
Hyperparameters:
num_layers: 2
filters_0: 32
kernel_size_0: 2
batch_norm_0: False
dropout_0: 0.1
filters_1: 64
kernel_size_1: 2
batch_norm_1: True
dropout_1: 0.5
learning_rate: 0.0073456414300114535
filters_2: 32
kernel_size_2: 3
batch_norm_2: False
dropout_2: 0.5
filters_3: 128
kernel_size_3: 2
batch_norm_3: True
dropout_3: 0.1
filters_4: 128
kernel_size_4: 2
batch_norm_4: True
dropout_4: 0.5
Score: 0.009512376127531752

Trial 15 summary
Hyperparameters:
num_layers: 4
filters_0: 64
kernel_size_0: 3
batch_norm_0: True
dropout_0: 0.2
filters_1: 128
kernel_size_1: 2
batch_norm_1: True
dropout_1: 0.4
learning_rate: 0.00015194032142750471
filters_2: 64
kernel_size_2: 3
batch_norm_2: False
dropout_2: 0.1
filters_3: 32
kernel_size_3: 3
batch_norm_3: False
dropout_3: 0.2
filters_4: 64
kernel_size_4: 2
batch_norm_4: True
dropout_4: 0.4
Score: 0.019518432789482176

Trial 18 summary
Hyperparameters:
num_layers: 3
filters_0: 64
kernel_size_0: 3
batch_norm_0: False
dropout_0: 0.30000000000000004
filters_1: 128
kernel_size_1: 2
batch_norm_1: True
dropout_1: 0.30000000000000004
learning_rate: 0.008041690224789656
filters_2: 32
kernel_size_2: 3
batch_norm_2: False
dropout_2: 0.4
filters_3: 32
kernel_size_3: 2
batch_norm_3: False
dropout_3: 0.5
filters_4: 64
kernel_size_4: 5
batch_norm_4: True
dropout_4: 0.2
Score: 0.030342670157551765

Trial 08 summary
Hyperparameters:
num_layers: 2
filters_0: 32
kernel_size_0: 5
batch_norm_0: False
dropout_0: 0.1
filters_1: 128
kernel_size_1: 2
batch_norm_1: True
dropout_1: 0.5
learning_rate: 0.00012595459853259762
filters_2: 64
kernel_size_2: 5
batch_norm_2: False
dropout_2: 0.2
filters_3: 128
kernel_size_3: 2
batch_norm_3: False
dropout_3: 0.4
filters_4: 32
kernel_size_4: 2
batch_norm_4: True
dropout_4: 0.1
Score: 0.030589942820370197

Trial 05 summary
Hyperparameters:
num_layers: 5
filters_0: 32
kernel_size_0: 3
batch_norm_0: True
dropout_0: 0.5
filters_1: 128
kernel_size_1: 2
batch_norm_1: True
dropout_1: 0.30000000000000004
learning_rate: 0.00023279265289587766
filters_2: 128
kernel_size_2: 3
batch_norm_2: True
dropout_2: 0.4
filters_3: 128
kernel_size_3: 5
batch_norm_3: False
dropout_3: 0.1
filters_4: 64
kernel_size_4: 5
batch_norm_4: False
dropout_4: 0.1
Score: 0.037598177907057106
Best model saved to: E:\minor\proj\code\saved_models\Brazil\TCN_final_model_16-11-2024-01-00-28.keras
31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.2526e-04 - mae: 0.0233
Validation Loss: 0.0012, Validation MAE: 0.0280
